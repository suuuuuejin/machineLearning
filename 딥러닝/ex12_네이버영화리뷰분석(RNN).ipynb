# %% [markdown]
# ### 네이버 영화리뷰 데이터로 감성분석 해보자(RNN)

# %%
# 한국어 형태소 분석기 설치
# !pip install Konlpy
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# Collecting Konlpy
#   Downloading konlpy-0.6.0-py2.py3-none-any.whl (19.4 MB)
#      |████████████████████████████████| 19.4 MB 1.2 MB/s
# Requirement already satisfied: numpy>=1.6 in /usr/local/lib/python3.7/dist-packages (from Konlpy) (1.21.6)
# Requirement already satisfied: lxml>=4.1.0 in /usr/local/lib/python3.7/dist-packages (from Konlpy) (4.9.1)
# Collecting JPype1>=0.7.0
#   Downloading JPype1-1.4.0-cp37-cp37m-manylinux_2_5_x86_64.manylinux1_x86_64.whl (453 kB)
#      |████████████████████████████████| 453 kB 67.9 MB/s
# Requirement already satisfied: typing-extensions in /usr/local/lib/python3.7/dist-packages (from JPype1>=0.7.0->Konlpy) (4.1.1)
# Installing collected packages: JPype1, Konlpy
# Successfully installed JPype1-1.4.0 Konlpy-0.6.0

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
from tensorflow.keras import Sequential
from tensorflow.keras.layers import Embedding, Dense, LSTM, GRU, Dropout, InputLayer #  Dropout: 과대적합 막아줌
from tensorflow.keras.preprocessing import sequence
from tensorflow.keras.preprocessing.text import Tokenizer
from tensorflow.keras.optimizers import Adam
from tensorflow.keras.callbacks import ModelCheckpoint, EarlyStopping
import pickle
from konlpy.tag import Okt
from tqdm import tqdm

# %% [markdown]
# ### 데이터 로딩

# %%
# %cd drive/MyDrive/Colab\ Notebooks
# Out:
# /content/drive/MyDrive/Colab Notebooks

# %%
# %pwd
# Out:
# '/content/drive/MyDrive/Colab Notebooks'

# %%
train = pd.read_csv('./data/ratings_train.csv')
test = pd.read_csv('./data/ratings_test.csv')

# %%
train.head()
# Out:
#          id                                           document  label
# 0   9976970                                아 더빙.. 진짜 짜증나네요 목소리      0
# 1   3819312                  흠...포스터보고 초딩영화줄....오버연기조차 가볍지 않구나      1
# 2  10265843                                  너무재밓었다그래서보는것을추천한다      0
# 3   9045019                      교도소 이야기구먼 ..솔직히 재미는 없다..평점 조정      0
# 4   6483659  사이몬페그의 익살스런 연기가 돋보였던 영화!스파이더맨에서 늙어보이기만 했던 커스틴 ...      1

# %%
# 결측치 제거
train.dropna(inplace=True)
test.dropna(inplace=True)

# %%
X_train = train['document']
y_train = train['label']
X_test = test['document']
y_test = test['label']

# %%
(X_train.shape, y_train.shape), (X_test.shape, y_test.shape)
# Out:
# (((149995,), (149995,)), ((49997,), (49997,)))

# %% [markdown]
# #### 형태소 추출

# %%
okt = Okt() # 형태소 분석기 생성

# %%
X_train_morphs = []

for doc in tqdm(X_train): # tqdm을 이용해서 반복횟수 시각화
  tmp = okt.morphs(doc) # 형태소 추출
  X_train_morphs.append(' '.join(tmp))
# Out:
# 100%|██████████| 149995/149995 [08:49<00:00, 283.16it/s]

# %%
X_test_morphs = []

for doc in tqdm(X_test): # tqdm을 이용해서 반복횟수 시각화
  tmp = okt.morphs(doc) # 형태소 추출
  X_test_morphs.append(' '.join(tmp))
# Out:
# 100%|██████████| 49997/49997 [02:49<00:00, 295.39it/s]

# %%
with open('./data/X_train_morphs.pkl','wb') as f:
  pickle.dump(X_train_morphs,f)

with open('./data/X_test_morphs.pkl','wb') as f:
  pickle.dump(X_test_morphs,f)

# %%
# pickle파일 로딩
with open('./data/X_train_morphs.pkl','rb') as f:
  x_train = pickle.load(f)

# %%
# pickle파일 로딩
with open('./data/X_test_morphs.pkl','rb') as f:
  x_test = pickle.load(f)

# %% [markdown]
# #### 빈도단위의 인코딩 진행

# %%
# 띄어쓰기 단위로 토큰화 및 단어 빈도를 기반으로 랭킹화(인코딩)
tokenizer = Tokenizer()

# %%
tokenizer.fit_on_texts(X_train)

# %%
tokenizer.word_index # 각 토큰들의 랭킹
# Out:
# {'영화': 1,
#  '너무': 2,
#  '정말': 3,
#  '진짜': 4,
#  '이': 5,
#  '그냥': 6,
#  '왜': 7,
#  '이런': 8,
#  '더': 9,
#  '수': 10,
#  '영화를': 11,
#  '다': 12,
#  '잘': 13,
#  '좀': 14,
#  '보고': 15,
#  'ㅋㅋ': 16,
#  '그': 17,
#  '영화는': 18,
#  '영화가': 19,
#  '본': 20,
#  '봤는데': 21,
#  '최고의': 22,
#  '아': 23,
#  '이건': 24,
#  '내가': 25,
#  '없는': 26,
#  '없다': 27,
#  '드라마': 28,
#  '완전': 29,
#  '이렇게': 30,
#  '참': 31,
#  '이거': 32,
#  '평점': 33,
#  '그리고': 34,
#  '이게': 35,
#  '좋은': 36,
#  '있는': 37,
#  '연기': 38,
#  '내': 39,
#  '평점이': 40,
#  '보는': 41,
#  '다시': 42,
#  '스토리': 43,
#  '역시': 44,
#  '최고': 45,
#  '쓰레기': 46,
#  '난': 47,
#  '많이': 48,
#  'ㅋ': 49,
#  '것': 50,
#  'ㅋㅋㅋ': 51,
#  '한': 52,
#  'ㅠㅠ': 53,
#  '재밌게': 54,
#  '없고': 55,
#  '또': 56,
#  '하는': 57,
#  '아깝다': 58,
#  '꼭': 59,
#  '보면': 60,
#  '가장': 61,
#  '마지막': 62,
#  '뭐': 63,
#  '영화다': 64,
#  '무슨': 65,
#  '하지만': 66,
#  'ㅡㅡ': 67,
#  'ㅎㅎ': 68,
#  '10점': 69,
#  '별로': 70,
#  '같은': 71,
#  '작품': 72,
#  '솔직히': 73,
#  '끝까지': 74,
#  '볼': 75,
#  '넘': 76,
#  '안': 77,
#  '대한': 78,
#  '만든': 79,
#  '와': 80,
#  '봐도': 81,
#  'ㅠ': 82,
#  '전혀': 83,
#  '그래도': 84,
#  '같다': 85,
#  '말이': 86,
#  '좋다': 87,
#  '지금': 88,
#  '아주': 89,
#  '뭔가': 90,
#  '있다': 91,
#  '영화의': 92,
#  '하고': 93,
#  '내내': 94,
#  '근데': 95,
#  '재미': 96,
#  '최악의': 97,
#  '다른': 98,
#  '굿': 99,
#  '할': 100,
#  '않고': 101,
#  '어떻게': 102,
#  '감독': 103,
#  '감동': 104,
#  '하나': 105,
#  '봤다': 106,
#  '연기가': 107,
#  '많은': 108,
#  '재밌다': 109,
#  '재미있게': 110,
#  '별': 111,
#  '이걸': 112,
#  '듯': 113,
#  '아니다': 114,
#  '중': 115,
#  '재미없다': 116,
#  '명작': 117,
#  '이야기': 118,
#  '연기도': 119,
#  '아니라': 120,
#  '보다가': 121,
#  '스토리가': 122,
#  '1점': 123,
#  '느낌': 124,
#  '아름다운': 125,
#  '차라리': 126,
#  '특히': 127,
#  '모두': 128,
#  '시간': 129,
#  '내용도': 130,
#  '나는': 131,
#  '액션': 132,
#  '계속': 133,
#  '제대로': 134,
#  '때문에': 135,
#  '내용이': 136,
#  '아니고': 137,
#  '나오는': 138,
#  '모든': 139,
#  '영화에': 140,
#  '연출': 141,
#  '제일': 142,
#  '감독이': 143,
#  '않은': 144,
#  '아직도': 145,
#  '스토리도': 146,
#  '때': 147,
#  '아닌': 148,
#  '도대체': 149,
#  '보다': 150,
#  '영화라고': 151,
#  '감독의': 152,
#  '시간이': 153,
#  '배우들': 154,
#  '영화입니다': 155,
#  '재미도': 156,
#  '여운이': 157,
#  '싶다': 158,
#  '마지막에': 159,
#  'ㅡ': 160,
#  '딱': 161,
#  '보면서': 162,
#  '나도': 163,
#  '오랜만에': 164,
#  '않는': 165,
#  '만드는': 166,
#  '한번': 167,
#  'ㅎ': 168,
#  '재밌어요': 169,
#  '걍': 170,
#  '좋았다': 171,
#  'ㅋㅋㅋㅋ': 172,
#  '진심': 173,
#  '나름': 174,
#  '아까운': 175,
#  '지루하고': 176,
#  '처음': 177,
#  '짱': 178,
#  '배우들의': 179,
#  '봤습니다': 180,
#  '좋고': 181,
#  '내용': 182,
#  '이제': 183,
#  '최고다': 184,
#  '이영화': 185,
#  '없음': 186,
#  '없이': 187,
#  '그런': 188,
#  '요즘': 189,
#  '절대': 190,
#  '보는내내': 191,
#  '개인적으로': 192,
#  '최악': 193,
#  '1점도': 194,
#  '좋아하는': 195,
#  '줄': 196,
#  '대박': 197,
#  '남는': 198,
#  '1': 199,
#  '조금': 200,
#  '보기': 201,
#  '주는': 202,
#  '보세요': 203,
#  '이해가': 204,
#  '못': 205,
#  '연기는': 206,
#  '얼마나': 207,
#  '아무리': 208,
#  '뻔한': 209,
#  'ㅜㅜ': 210,
#  '그저': 211,
#  '영화로': 212,
#  '전': 213,
#  '영화도': 214,
#  '너무나': 215,
#  '재미가': 216,
#  '제발': 217,
#  '기억에': 218,
#  '생각이': 219,
#  '엄청': 220,
#  '멋진': 221,
#  '봤던': 222,
#  '한국': 223,
#  '되는': 224,
#  '주인공': 225,
#  '배우': 226,
#  '강추': 227,
#  '괜찮은': 228,
#  '극장에서': 229,
#  '있고': 230,
#  '결국': 231,
#  '지루하다': 232,
#  '그래서': 233,
#  '그렇게': 234,
#  '매우': 235,
#  '게': 236,
#  '사람이': 237,
#  '내용은': 238,
#  '돈': 239,
#  '나': 240,
#  '좋아요': 241,
#  '위해': 242,
#  '두': 243,
#  '하나도': 244,
#  '그나마': 245,
#  '봤어요': 246,
#  '인생': 247,
#  '모르겠다': 248,
#  '싶은': 249,
#  '것이': 250,
#  '영화네요': 251,
#  '함께': 252,
#  '건': 253,
#  '가슴이': 254,
#  '개': 255,
#  '안되는': 256,
#  '위한': 257,
#  '한다': 258,
#  '마음이': 259,
#  '코미디': 260,
#  '지루한': 261,
#  '않는다': 262,
#  '갈수록': 263,
#  '뭘': 264,
#  '같이': 265,
#  '아니': 266,
#  '못한': 267,
#  '사랑': 268,
#  '재미없음': 269,
#  '된': 270,
#  '연기를': 271,
#  '재밌는': 272,
#  '눈물이': 273,
#  '재밌음': 274,
#  '어떤': 275,
#  '것도': 276,
#  '간만에': 277,
#  '큰': 278,
#  '2': 279,
#  '밖에': 280,
#  '재밌고': 281,
#  '대체': 282,
#  '것을': 283,
#  '사람': 284,
#  '꽤': 285,
#  '훨씬': 286,
#  '다들': 287,
#  '거': 288,
#  '아쉽다': 289,
#  'good': 290,
#  '나온': 291,
#  '저': 292,
#  '장면': 293,
#  '기억이': 294,
#  '영화중': 295,
#  '결말이': 296,
#  '누가': 297,
#  '보지': 298,
#  '스릴러': 299,
#  '감동도': 300,
#  '영화관에서': 301,
#  '어설픈': 302,
#  '스토리는': 303,
#  '진정한': 304,
#  '전개': 305,
#  '했는데': 306,
#  '아님': 307,
#  '없었다': 308,
#  '추천': 309,
#  '좋은데': 310,
#  '우리': 311,
#  '생각을': 312,
#  '사람들이': 313,
#  '상당히': 314,
#  '배우들이': 315,
#  '않다': 316,
#  '영화였다': 317,
#  '오늘': 318,
#  '뭔': 319,
#  '대해': 320,
#  '정도': 321,
#  '잔잔한': 322,
#  '생각보다': 323,
#  '정도로': 324,
#  '걸': 325,
#  '일본': 326,
#  '그러나': 327,
#  '여자': 328,
#  '지루함': 329,
#  '수작': 330,
#  '감동을': 331,
#  '중간에': 332,
#  '졸작': 333,
#  '같은데': 334,
#  '감동적인': 335,
#  '같아요': 336,
#  '바로': 337,
#  '음': 338,
#  '결말': 339,
#  '느낌이': 340,
#  '뭐지': 341,
#  '반전': 342,
#  '연기력': 343,
#  '재미있어요': 344,
#  '보여주는': 345,
#  '보니': 346,
#  '우리나라': 347,
#  '하': 348,
#  '있지만': 349,
#  '주고': 350,
#  '있을까': 351,
#  '수준': 352,
#  '봤지만': 353,
#  '보게': 354,
#  '원작을': 355,
#  '재미는': 356,
#  '나와서': 357,
#  '준다': 358,
#  '해서': 359,
#  '굉장히': 360,
#  '거의': 361,
#  '음악': 362,
#  'ㅉㅉ': 363,
#  '갑자기': 364,
#  '재미있다': 365,
#  '재밌네요': 366,
#  '나의': 367,
#  '뭐야': 368,
#  '장면이': 369,
#  '말': 370,
#  '평점을': 371,
#  '기대': 372,
#  '될': 373,
#  '영화인데': 374,
#  '당시': 375,
#  '존나': 376,
#  '사람들': 377,
#  '자체가': 378,
#  '마음에': 379,
#  '이영화를': 380,
#  '약간': 381,
#  '쓰레기영화': 382,
#  '저는': 383,
#  '제가': 384,
#  'ㅜ': 385,
#  '알고': 386,
#  '봐라': 387,
#  '영화임': 388,
#  '하다': 389,
#  '훌륭한': 390,
#  '충분히': 391,
#  '일단': 392,
#  '있어서': 393,
#  '한마디로': 394,
#  '재미있는': 395,
#  '사람은': 396,
#  '항상': 397,
#  '그대로': 398,
#  '그런지': 399,
#  '하지': 400,
#  '감독은': 401,
#  '긴장감': 402,
#  '것은': 403,
#  '막장': 404,
#  '비해': 405,
#  '시리즈': 406,
#  '어디서': 407,
#  '말도': 408,
#  '아까움': 409,
#  '뭐냐': 410,
#  '봐서': 411,
#  '없어서': 412,
#  '처음부터': 413,
#  '주인공이': 414,
#  '기분': 415,
#  '노잼': 416,
#  '새로운': 417,
#  '있는데': 418,
#  '볼만한': 419,
#  '후': 420,
#  '준': 421,
#  '가지고': 422,
#  '몰입도': 423,
#  '좋네요': 424,
#  '이영화는': 425,
#  'b급': 426,
#  '합니다': 427,
#  '맘에': 428,
#  '평점은': 429,
#  '아직': 430,
#  '수가': 431,
#  '♥': 432,
#  '전개가': 433,
#  '점점': 434,
#  '했다': 435,
#  '이딴': 436,
#  '도저히': 437,
#  '다시봐도': 438,
#  '봤음': 439,
#  '뭐가': 440,
#  '그게': 441,
#  '오히려': 442,
#  '가슴': 443,
#  'oo': 444,
#  '사람들은': 445,
#  '생각': 446,
#  '재밌는데': 447,
#  '더욱': 448,
#  '대사': 449,
#  '물론': 450,
#  '무조건': 451,
#  '감동이': 452,
#  '애니메이션': 453,
#  '이것도': 454,
#  '사랑을': 455,
#  '캐릭터': 456,
#  'ㅎㅎㅎ': 457,
#  '보는데': 458,
#  '재미없는': 459,
#  '뿐': 460,
#  '생각하게': 461,
#  '전부': 462,
#  '없어': 463,
#  '엄청난': 464,
#  '전형적인': 465,
#  '시나리오': 466,
#  '대단한': 467,
#  '그만': 468,
#  '실망': 469,
#  '모르고': 470,
#  '제': 471,
#  '평점에': 472,
#  '해도': 473,
#  '라는': 474,
#  '좋겠다': 475,
#  '예전에': 476,
#  '3': 477,
#  '액션도': 478,
#  '없네': 479,
#  '입니다': 480,
#  '이야기를': 481,
#  '인간의': 482,
#  '따뜻한': 483,
#  '애니': 484,
#  '배우가': 485,
#  '원래': 486,
#  '지금도': 487,
#  '완벽한': 488,
#  '걸작': 489,
#  '헐': 490,
#  '봤네요': 491,
#  '재밌었다': 492,
#  '그닥': 493,
#  '4': 494,
#  '듯한': 495,
#  '만들어': 496,
#  '3류': 497,
#  '억지로': 498,
#  '남자': 499,
#  '것이다': 500,
#  '별점': 501,
#  '너무너무': 502,
#  '없네요': 503,
#  '영': 504,
#  '공포': 505,
#  '좋았어요': 506,
#  '하면': 507,
#  '네이버': 508,
#  '봄': 509,
#  '저도': 510,
#  '아무것도': 511,
#  '말고': 512,
#  '더럽게': 513,
#  '된다': 514,
#  '처음으로': 515,
#  '원작': 516,
#  '가': 517,
#  '자꾸': 518,
#  '우연히': 519,
#  '억지': 520,
#  '특유의': 521,
#  '그런데': 522,
#  '낫다': 523,
#  '이미': 524,
#  '좋음': 525,
#  '재미있고': 526,
#  '안된다': 527,
#  '좋아': 528,
#  '돈이': 529,
#  '아닌가': 530,
#  '있음': 531,
#  '그의': 532,
#  '몇': 533,
#  '돈주고': 534,
#  '장면은': 535,
#  '공포영화': 536,
#  '유치하고': 537,
#  '알았는데': 538,
#  '또한': 539,
#  '못하는': 540,
#  '재미없고': 541,
#  '빨리': 542,
#  '한국영화': 543,
#  '명작이다': 544,
#  '이런걸': 545,
#  '눈물': 546,
#  '마치': 547,
#  '화이팅': 548,
#  '유치한': 549,
#  '알았다': 550,
#  '영화라': 551,
#  '영화보다': 552,
#  '느낄': 553,
#  '최악이다': 554,
#  '사실': 555,
#  '중에': 556,
#  '있었다': 557,
#  '알': 558,
#  '믿고': 559,
#  '저런': 560,
#  '연출이': 561,
#  '아이들이': 562,
#  '마음을': 563,
#  '미친': 564,
#  '영화에서': 565,
#  '영상': 566,
#  '스토리에': 567,
#  '너무나도': 568,
#  '왜이리': 569,
#  '아니지만': 570,
#  '이상': 571,
#  '잘봤습니다': 572,
#  '0': 573,
#  '모습이': 574,
#  '그렇고': 575,
#  '애들': 576,
#  '소재는': 577,
#  '어느': 578,
#  '하게': 579,
#  '뭔지': 580,
#  '아니면': 581,
#  '이젠': 582,
#  '드라마를': 583,
#  '지금봐도': 584,
#  '로맨스': 585,
#  '지금까지': 586,
#  '괜히': 587,
#  '않음': 588,
#  '별로다': 589,
#  '다만': 590,
#  'ooo': 591,
#  '막': 592,
#  '하는데': 593,
#  '어릴때': 594,
#  '같습니다': 595,
#  '이해': 596,
#  '기대하고': 597,
#  '삶을': 598,
#  '왠지': 599,
#  '진부한': 600,
#  '이야기가': 601,
#  '흠': 602,
#  '못하고': 603,
#  '감사합니다': 604,
#  '이런게': 605,
#  '영화였습니다': 606,
#  '앞으로': 607,
#  '감독님': 608,
#  '드라마가': 609,
#  '확실히': 610,
#  '전체적으로': 611,
#  '좋았습니다': 612,
#  '좋았고': 613,
#  '웃음': 614,
#  '느끼게': 615,
#  '화려한': 616,
#  '무엇보다': 617,
#  '재밌었어요': 618,
#  '만들지': 619,
#  '의': 620,
#  '다소': 621,
#  '여자가': 622,
#  '역시나': 623,
#  '자신의': 624,
#  '아놔': 625,
#  '소재': 626,
#  '영화이다': 627,
#  '모습을': 628,
#  '이영화가': 629,
#  '혼자': 630,
#  '좋았는데': 631,
#  '영화중에': 632,
#  '했지만': 633,
#  '스토리와': 634,
#  '대단하다': 635,
#  '액션은': 636,
#  '끝': 637,
#  '영화지만': 638,
#  '굳': 639,
#  '발연기': 640,
#  '재미없어': 641,
#  '있어': 642,
#  '보지마세요': 643,
#  '날': 644,
#  '나를': 645,
#  '여전히': 646,
#  '이런영화': 647,
#  '같네요': 648,
#  '여주인공': 649,
#  '않았다': 650,
#  '가는': 651,
#  '눈이': 652,
#  '비슷한': 653,
#  '내용을': 654,
#  '볼때마다': 655,
#  '본다': 656,
#  '좋았음': 657,
#  '생각한다': 658,
#  '어렸을때': 659,
#  '허접한': 660,
#  '있다는': 661,
#  '아쉬운': 662,
#  'tv': 663,
#  'ㅅㅂ': 664,
#  '모르는': 665,
#  '부분이': 666,
#  '연기에': 667,
#  '캐스팅': 668,
#  '그런가': 669,
#  '점수': 670,
#  '있다면': 671,
#  '5': 672,
#  '드라마는': 673,
#  '매력적인': 674,
#  '소재를': 675,
#  '스토리를': 676,
#  '보고나서': 677,
#  '아닐까': 678,
#  '반전이': 679,
#  '봐야': 680,
#  '이런거': 681,
#  '든다': 682,
#  '순수한': 683,
#  '함': 684,
#  '8': 685,
#  '사람을': 686,
#  '처음이다': 687,
#  '유쾌한': 688,
#  '왜이렇게': 689,
#  '추천합니다': 690,
#  'ㄷㄷ': 691,
#  '세상에': 692,
#  '높은': 693,
#  '나만': 694,
#  '보는게': 695,
#  'ㅋㅋㅋㅋㅋ': 696,
#  '그들의': 697,
#  '슬픈': 698,
#  '지난': 699,
#  '아무': 700,
#  '깊은': 701,
#  '7': 702,
#  '부족한': 703,
#  '과연': 704,
#  '전에': 705,
#  '보기엔': 706,
#  '이리': 707,
#  '연기와': 708,
#  '봤었는데': 709,
#  '어이없는': 710,
#  '굳이': 711,
#  '옛날': 712,
#  '있을': 713,
#  '액션이': 714,
#  '주인공의': 715,
#  '이유가': 716,
#  '난다': 717,
#  '귀엽고': 718,
#  '나오고': 719,
#  '통해': 720,
#  '노래': 721,
#  '영화보고': 722,
#  '삼류': 723,
#  '눈을': 724,
#  '감동적이고': 725,
#  '연기력이': 726,
#  '꿀잼': 727,
#  '개연성': 728,
#  '재미있음': 729,
#  '아름답고': 730,
#  '이정도면': 731,
#  '언제': 732,
#  '등': 733,
#  '음악이': 734,
#  '아닌데': 735,
#  '에휴': 736,
#  '정말로': 737,
#  '슬프다': 738,
#  '재밌었는데': 739,
#  '현실을': 740,
#  '먼저': 741,
#  '아름답다': 742,
#  '졸라': 743,
#  '안되고': 744,
#  '안하고': 745,
#  '전기세가': 746,
#  '2점': 747,
#  '마라': 748,
#  '독특한': 749,
#  '매력이': 750,
#  '오': 751,
#  '안됨': 752,
#  '어색한': 753,
#  '기대를': 754,
#  '봤다가': 755,
#  '있었던': 756,
#  '남는다': 757,
#  '힘든': 758,
#  '느껴지는': 759,
#  '보여준': 760,
#  '음악도': 761,
#  '나온다': 762,
#  '재미를': 763,
#  '마음': 764,
#  '생각합니다': 765,
#  '보시길': 766,
#  '평범한': 767,
#  '해준': 768,
#  '재밌습니다': 769,
#  '진심으로': 770,
#  '그럭저럭': 771,
#  '같음': 772,
#  'the': 773,
#  '좋은영화': 774,
#  '이유는': 775,
#  '참고': 776,
#  '영화냐': 777,
#  '그다지': 778,
#  '지루해서': 779,
#  '하면서': 780,
#  '처음엔': 781,
#  '배우의': 782,
#  '90년대': 783,
#  '저렇게': 784,
#  '연출도': 785,
#  '감동과': 786,
#  '80년대': 787,
#  '역대': 788,
#  '사람의': 789,
#  '판타지': 790,
#  '중간중간': 791,
#  '보이는': 792,
#  '볼수': 793,
#  '사랑에': 794,
#  '티비에서': 795,
#  '귀여운': 796,
#  '우리가': 797,
#  '이상한': 798,
#  '질질': 799,
#  '9점': 800,
#  '살짝': 801,
#  '볼수록': 802,
#  '구성': 803,
#  '그럼': 804,
#  '사랑이': 805,
#  '공감이': 806,
#  '재미없네': 807,
#  '삶의': 808,
#  '나왔으면': 809,
#  '10': 810,
#  '라고': 811,
#  '필요없다': 812,
#  '휴': 813,
#  '신선한': 814,
#  '볼만함': 815,
#  '소재가': 816,
#  '지루해': 817,
#  '하네요': 818,
#  '없지만': 819,
#  '봤으면': 820,
#  '몰라도': 821,
#  '나에게': 822,
#  '좋습니다': 823,
#  '되었다': 824,
#  '게다가': 825,
#  '대충': 826,
#  '몰입이': 827,
#  '나중에': 828,
#  '여기': 829,
#  '지루하지': 830,
#  '9': 831,
#  '배우들도': 832,
#  '필요없는': 833,
#  '이건뭐': 834,
#  '해주는': 835,
#  '지루': 836,
#  '추억의': 837,
#  '제목이': 838,
#  '딱히': 839,
#  '알게': 840,
#  '사랑하는': 841,
#  '좋아서': 842,
#  '아닌듯': 843,
#  '언제나': 844,
#  '결말은': 845,
#  '속': 846,
#  '그리': 847,
#  '아오': 848,
#  '제목': 849,
#  '반전도': 850,
#  '지금은': 851,
#  '했던': 852,
#  'ost': 853,
#  '만들어진': 854,
#  '드는': 855,
#  '끝나고': 856,
#  '여주': 857,
#  '미국': 858,
#  '엔딩': 859,
#  '번': 860,
#  '떨어지는': 861,
#  '마세요': 862,
#  '애들이': 863,
#  '인생을': 864,
#  '가서': 865,
#  '시간을': 866,
#  '단': 867,
#  'ㅠㅠㅠ': 868,
#  '더이상': 869,
#  '점수를': 870,
#  '자기': 871,
#  '만들': 872,
#  '이후': 873,
#  '기분이': 874,
#  '작가': 875,
#  '밑에': 876,
#  '어린': 877,
#  '쓴': 878,
#  '가볍게': 879,
#  '필요': 880,
#  '비추': 881,
#  '단지': 882,
#  '글쎄': 883,
#  '3점': 884,
#  '서로': 885,
#  '0점': 886,
#  '않게': 887,
#  '대한민국': 888,
#  '있지': 889,
#  '그래': 890,
#  '재미있네요': 891,
#  '각본': 892,
#  '않을': 893,
#  '있습니다': 894,
#  '슬프고': 895,
#  '를': 896,
#  '와우': 897,
#  '싫다': 898,
#  '불구하고': 899,
#  '웃기고': 900,
#  '아까워': 901,
#  '매력': 902,
#  '건지': 903,
#  '짜증나는': 904,
#  '쉽게': 905,
#  '봐야할': 906,
#  '크게': 907,
#  '짜증': 908,
#  '암튼': 909,
#  '가진': 910,
#  '까지': 911,
#  '시대를': 912,
#  '만큼': 913,
#  '보고싶다': 914,
#  '현실': 915,
#  '킬링타임용': 916,
#  '멋지다': 917,
#  '사랑과': 918,
#  '낮아서': 919,
#  '눈물을': 920,
#  '부터': 921,
#  '쩝': 922,
#  '분위기': 923,
#  '결말도': 924,
#  '어이가': 925,
#  '엉성한': 926,
#  '이제야': 927,
#  '있나': 928,
#  '수도': 929,
#  '설정': 930,
#  '만': 931,
#  '겁나': 932,
#  '열심히': 933,
#  '좀더': 934,
#  '만들고': 935,
#  '더빙': 936,
#  '지': 937,
#  '죄다': 938,
#  '프랑스': 939,
#  '되게': 940,
#  '내인생': 941,
#  '보니까': 942,
#  '소재로': 943,
#  '0점은': 944,
#  '실제': 945,
#  '느낌을': 946,
#  '있게': 947,
#  '한데': 948,
#  '단순한': 949,
#  '봣는데': 950,
#  '만들었다': 951,
#  '잔잔하고': 952,
#  '무엇을': 953,
#  '그렇다고': 954,
#  '같아': 955,
#  '모든게': 956,
#  '작품이': 957,
#  '둘다': 958,
#  '알바': 959,
#  '잘만든': 960,
#  '있어요': 961,
#  '되지': 962,
#  '뻔하고': 963,
#  '말을': 964,
#  'ooo기': 965,
#  '못했다': 966,
#  '처럼': 967,
#  '뛰어난': 968,
#  '없을': 969,
#  '모습': 970,
#  '재밌었음': 971,
#  '사랑스러운': 972,
#  '이런영화가': 973,
#  '망작': 974,
#  '맞는': 975,
#  '같아서': 976,
#  '남자가': 977,
#  '잼있게': 978,
#  '몇번을': 979,
#  '아는': 980,
#  '않지만': 981,
#  '안타깝다': 982,
#  '재미있었다': 983,
#  '사는': 984,
#  '재미없어요': 985,
#  '생애': 986,
#  '만화': 987,
#  '시절': 988,
#  '작가가': 989,
#  '나옴': 990,
#  '평생': 991,
#  '누구나': 992,
#  '떠나서': 993,
#  '극장판': 994,
#  '그걸': 995,
#  '가끔': 996,
#  '여배우': 997,
#  '옛날에': 998,
#  '4점': 999,
#  '가족': 1000,
#  ...}

# %%
tokenizer.word_counts
# Out:
# OrderedDict([('아', 2164),
#              ('더빙', 131),
#              ('진짜', 6682),
#              ('짜증나네요', 18),
#              ('목소리', 113),
#              ('흠', 190),
#              ('포스터보고', 20),
#              ('초딩영화줄', 1),
#              ('오버연기조차', 1),
#              ('가볍지', 17),
#              ('않구나', 3),
#              ('너무재밓었다그래서보는것을추천한다', 1),
#              ('교도소', 4),
#              ('이야기구먼', 1),
#              ('솔직히', 993),
#              ('재미는', 309),
#              ('없다', 2019),
#              ('평점', 1862),
#              ('조정', 11),
#              ('사이몬페그의', 1),
#              ('익살스런', 2),
#              ('연기가', 767),
#              ('돋보였던', 23),
#              ('영화', 18995),
#              ('스파이더맨에서', 1),
#              ('늙어보이기만', 1),
#              ('했던', 140),
#              ('커스틴', 4),
#              ('던스트가', 1),
#              ('너무나도', 198),
#              ('이뻐보였다', 1),
#              ('막', 193),
#              ('걸음마', 1),
#              ('뗀', 2),
#              ('3세부터', 1),
#              ('초등학교', 55),
#              ('1학년생인', 1),
#              ('8살용영화', 1),
#              ('ㅋㅋㅋ', 1380),
#              ('별반개도', 29),
#              ('아까움', 271),
#              ('원작의', 113),
#              ('긴장감을', 56),
#              ('제대로', 666),
#              ('살려내지못했다', 1),
#              ('별', 760),
#              ('반개도', 98),
#              ('아깝다', 1282),
#              ('욕나온다', 46),
#              ('이응경', 3),
#              ('길용우', 1),
#              ('연기생활이몇년인지', 1),
#              ('정말', 8537),
#              ('발로해도', 1),
#              ('그것보단', 4),
#              ('낫겟다', 2),
#              ('납치', 13),
#              ('감금만반복반복', 1),
#              ('이드라마는', 13),
#              ('가족도없다', 1),
#              ('연기못하는사람만모엿네', 1),
#              ('액션이', 164),
#              ('없는데도', 5),
#              ('재미', 832),
#              ('있는', 1771),
#              ('몇안되는', 25),
#              ('왜케', 104),
#              ('평점이', 1658),
#              ('낮은건데', 1),
#              ('꽤', 363),
#              ('볼만한데', 38),
#              ('헐리우드식', 12),
#              ('화려함에만', 1),
#              ('너무', 8563),
#              ('길들여져', 3),
#              ('있나', 132),
#              ('걍인피니트가짱이다', 1),
#              ('진짜짱이다♥', 1),
#              ('볼때마다', 176),
#              ('눈물나서', 2),
#              ('죽겠다90년대의', 1),
#              ('향수자극', 1),
#              ('허진호는', 1),
#              ('감성절제멜로의', 1),
#              ('달인이다', 3),
#              ('울면서', 56),
#              ('손들고', 1),
#              ('횡단보도', 1),
#              ('건널때', 1),
#              ('뛰쳐나올뻔', 1),
#              ('이범수', 20),
#              ('연기', 1759),
#              ('드럽게못해', 1),
#              ('담백하고', 12),
#              ('깔끔해서', 5),
#              ('좋다', 880),
#              ('신문기사로만', 1),
#              ('보다', 614),
#              ('보면', 1235),
#              ('자꾸', 216),
#              ('잊어버린다', 1),
#              ('그들도', 10),
#              ('사람이었다는', 1),
#              ('것을', 367),
#              ('취향은', 34),
#              ('존중한다지만', 1),
#              ('내생에', 64),
#              ('극장에서', 444),
#              ('본', 2312),
#              ('영화중', 354),
#              ('가장', 1192),
#              ('노잼', 267),
#              ('노감동임', 1),
#              ('스토리도', 628),
#              ('어거지고', 2),
#              ('감동도', 349),
#              ('어거지', 24),
#              ('ㄱ냥', 1),
#              ('매번', 54),
#              ('긴장되고', 8),
#              ('재밋음ㅠㅠ', 1),
#              ('참', 1887),
#              ('사람들', 291),
#              ('웃긴게', 12),
#              ('바스코가', 2),
#              ('이기면', 5),
#              ('락스코라고', 1),
#              ('까고바비가', 1),
#              ('아이돌이라고', 1),
#              ('깐다', 2),
#              ('그냥', 3596),
#              ('까고싶어서', 1),
#              ('안달난것처럼', 1),
#              ('보인다', 112),
#              ('굿바이', 15),
#              ('레닌', 2),
#              ('표절인것은', 1),
#              ('이해하는데', 6),
#              ('왜', 3512),
#              ('뒤로', 91),
#              ('갈수록', 403),
#              ('재미없어지냐', 1),
#              ('이건', 2133),
#              ('깨알', 7),
#              ('캐스팅과', 12),
#              ('질퍽하지않은', 1),
#              ('산뜻한', 6),
#              ('내용구성이', 2),
#              ('잘', 2693),
#              ('버무러진', 2),
#              ('깨알일드', 1),
#              ('♥', 256),
#              ('약탈자를', 1),
#              ('위한', 412),
#              ('변명', 7),
#              ('이라', 15),
#              ('저놈들은', 1),
#              ('착한놈들', 1),
#              ('절대', 524),
#              ('아닌걸요', 1),
#              ('나름', 561),
#              ('심오한', 30),
#              ('뜻도', 7),
#              ('듯', 749),
#              ('학생이', 6),
#              ('선생과', 3),
#              ('놀아나는', 9),
#              ('영화는', 2514),
#              ('아님', 341),
#              ('보면서', 594),
#              ('웃지', 13),
#              ('않는', 588),
#              ('건', 414),
#              ('불가능하다', 7),
#              ('재미없다', 735),
#              ('지루하고', 559),
#              ('같은', 1004),
#              ('음식', 19),
#              ('영화인데도', 30),
#              ('바베트의', 2),
#              ('만찬하고', 1),
#              ('넘', 962),
#              ('차이남', 1),
#              ('만찬은', 1),
#              ('이야기도', 33),
#              ('있고', 442),
#              ('보는재미도', 3),
#              ('있는데', 265),
#              ('볼게없다', 11),
#              ('음식도', 1),
#              ('별로', 1020),
#              ('안나오고', 38),
#              ('핀란드', 4),
#              ('풍경이라도', 1),
#              ('구경할랫는데', 1),
#              ('그것도', 96),
#              ('안나옴', 43),
#              ('ㅡㅡ', 1107),
#              ('평범한', 155),
#              ('영화가', 2503),
#              ('아닌', 622),
#              ('수작이라는걸', 1),
#              ('말씀드립니다', 2),
#              ('주제는', 41),
#              ('좋은데', 339),
#              ('중반부터', 39),
#              ('지루하다', 437),
#              ('다', 2715),
#              ('짤랐을꺼야', 1),
#              ('그래서', 437),
#              ('납득할', 4),
#              ('수', 2951),
#              ('없었던거야', 1),
#              ('그럴꺼야', 1),
#              ('꼭', 1255),
#              ('그랬던걸꺼야', 1),
#              ('kl2g', 1),
#              ('고추를', 1),
#              ('털어버려야', 1),
#              ('할텐데', 17),
#              ('카밀라벨', 2),
#              ('발연기', 179),
#              ('재밋는뎅', 1),
#              ('센스있는', 9),
#              ('연출력', 120),
#              ('탁월한', 42),
#              ('캐스팅', 173),
#              ('90년대의', 10),
#              ('향수', 7),
#              ('9점', 149),
#              ('엄포스의', 1),
#              ('위력을', 4),
#              ('다시', 1640),
#              ('한번', 577),
#              ('깨닫게', 84),
#              ('해준', 155),
#              ('적', 49),
#              ('남', 67),
#              ('꽃검사님도', 1),
#              ('좋았어요', 221),
#              ('완전', 1915),
#              ('명품드라마', 8),
#              ('졸쓰레기', 1),
#              ('진부하고말도안됌ㅋㅋ', 1),
#              ('시간아까워', 31),
#              ('재밌는데', 249),
#              ('별점이', 48),
#              ('왜이리', 198),
#              ('낮은고', 1),
#              ('1', 507),
#              ('라도', 6),
#              ('기대했던', 31),
#              ('내가', 2126),
#              ('죄인입니다', 2),
#              ('아직도', 637),
#              ('이', 5418),
#              ('드라마는', 172),
#              ('내인생의', 15),
#              ('최고', 1610),
#              ('패션에', 2),
#              ('대한', 942),
#              ('열정', 22),
#              ('안나', 22),
#              ('윈투어', 1),
#              ('키이라', 10),
#              ('나이틀리가', 2),
#              ('연기하고자', 1),
#              ('했던건', 3),
#              ('대체', 368),
#              ('정신장애일까', 1),
#              ('틱장애일까', 1),
#              ('허허', 49),
#              ('원작가', 3),
#              ('정신나간', 27),
#              ('유령이라', 1),
#              ('재미있겠네요', 2),
#              ('포스터는', 29),
#              ('있어보이는데', 1),
#              ('관객은', 21),
#              ('114명이네', 1),
#              ('이렇게', 1900),
#              ('저평가', 21),
#              ('받는지', 5),
#              ('모르겠다', 423),
#              ('단순하면서', 2),
#              ('은은한', 20),
#              ('매력의', 16),
#              ("'다", 2),
#              ('알바생인가', 5),
#              ('내용도', 692),
#              ('없고', 1351),
#              ('무서운거도', 1),
#              ('웃긴거도', 1),
#              ('하나도', 425),
#              ('없음', 532),
#              ('별싱거운', 1),
#              ('ㅇ', 91),
#              ('ㅇ내ㅇ시간', 1),
#              ('낚임', 21),
#              ('오게두어라', 1),
#              ('서리한이', 1),
#              ('굶주렸다', 1),
#              ('맘에', 257),
#              ('들어요', 19),
#              ('또', 1305),
#              ('보고싶은데', 49),
#              ('보는', 1647),
#              ('방법이', 27),
#              ('없네', 232),
#              ('ㅜㅡ', 9),
#              ('윤제문이라는', 1),
#              ('멋진', 461),
#              ('배우를', 94),
#              ('발견하게', 7),
#              ('됐어요', 17),
#              ('소소한', 77),
#              ('일탈이', 3),
#              ('잔잔한', 334),
#              ('미소를', 30),
#              ('머금게', 3),
#              ('합니다', 258),
#              ('음악은', 56),
#              ('조금', 501),
#              ('아쉽네요ㅠㅠ', 3),
#              ('8점', 105),
#              ('주고', 313),
#              ('싶은데', 102),
#              ('올리고', 13),
#              ('싶어', 53),
#              ('10점', 1050),
#              ('줄게요', 2),
#              ('평점에속지마시길시간낭비', 1),
#              ('돈낭비임', 2),
#              ('리얼리티가', 14),
#              ('뛰어나긴', 1),
#              ('한데', 129),
#              ('큰', 378),
#              ('공감은', 24),
#              ('안간다', 71),
#              ('이민기캐릭터는', 1),
#              ('정신의학상', 1),
#              ('분노조절장애', 2),
#              ('초기', 13),
#              ('증상일거다', 1),
#              ('툭하면', 12),
#              ('사람패고', 2),
#              ('욕하고', 24),
#              ('물건', 4),
#              ('파손하고', 1),
#              ('오바였음', 2),
#              ('극', 26),
#              ('초반엔', 51),
#              ('신선했는데', 8),
#              ('가면', 61),
#              ('이민기', 15),
#              ('정신상태', 4),
#              ('공감불가', 2),
#              ('마이너스는', 23),
#              ('왜없냐', 2),
#              ('ㅋ', 1464),
#              ('뮤비', 6),
#              ('보고', 2632),
#              ('영화수준', 7),
#              ('딱', 595),
#              ('알만하더군', 1),
#              ('ㅉㅉ', 303),
#              ('북한에서', 6),
#              ('이런거', 170),
#              ('만들라고', 8),
#              ('돈', 428),
#              ('대주던', 1),
#              ('난', 1521),
#              ('우리영화를', 1),
#              ('사랑합니다', 64),
#              ('데너리스', 1),
#              ('타르', 2),
#              ('가르엔', 1),
#              ('나도', 594),
#              ('용의주인이', 1),
#              ('되고', 123),
#              ('싶다', 599),
#              ('누이랑', 1),
#              ('근친상간이나', 1),
#              ('하고', 848),
#              ('다닐지라도', 1),
#              ('소설', 57),
#              ('속에선', 2),
#              ('제일', 648),
#              ('놈이', 24),
#              ('자이메', 1),
#              ('라니스터였는데', 1),
#              ('드라마속에선', 1),
#              ('드래곤', 10),
#              ('용', 15),
#              ('멋지네', 10),
#              ('웃음', 187),
#              ('감독님', 188),
#              ('토르', 11),
#              ('2', 376),
#              ('다크', 15),
#              ('월드는', 1),
#              ('말아', 11),
#              ('잡수셨을지라도', 1),
#              ('기본', 42),
#              ('선방은', 1),
#              ('했음', 69),
#              ('사람의', 151),
#              ('영혼을', 29),
#              ('어루만져', 2),
#              ('줄', 517),
#              ('수도', 132),
#              ('있군요', 14),
#              ('거친', 19),
#              ('세상사를', 1),
#              ('잠시', 47),
#              ('잊고', 57),
#              ('동화같은', 46),
#              ('영화에', 653),
#              ('행복했네요', 1),
#              ('야', 81),
#              ('세르게이', 6),
#              ('작은고추의', 2),
#              ('매운맛을', 4),
#              ('보여주마', 4),
#              ('포퐁저그', 1),
#              ('콩진호가', 5),
#              ('간다', 96),
#              ('가슴시리게', 1),
#              ('드라마가', 188),
#              ('있을까', 313),
#              ('감동', 782),
#              ('그', 2546),
#              ('자체', 110),
#              ('난또', 6),
#              ('저', 355),
#              ('꼬마애가', 3),
#              ('무슨', 1115),
#              ('원한이', 2),
#              ('깊길래', 1),
#              ('했더니', 55),
#              ('oo', 251),
#              ('혼자', 181),
#              ('나대다', 1),
#              ('oo걸', 1),
#              ('어쩌라고', 30),
#              ('재미있어요', 317),
#              ('전', 486),
#              ('좋아요', 427),
#              ('충격적이엇다', 1),
#              ('기분을', 16),
#              ('완전히', 111),
#              ('푹', 92),
#              ('꺼지게', 2),
#              ('하는', 1301),
#              ('느낌', 702),
#              ('활력이라고는', 1),
#              ('없는', 2050),
#              ('무거운', 50),
#              ('지독하고', 5),
#              ('차갑고', 7),
#              ('무자비하다', 1),
#              ('그저', 489),
#              ('일본인들의', 3),
#              ('상상력은', 14),
#              ('대단한거', 3),
#              ('같다는', 24),
#              ('생각이', 469),
#              ('든다', 170),
#              ('심심한영화', 4),
#              ('백봉기', 1),
#              ('언제나오나요', 2),
#              ('보는내내', 522),
#              ('그대로', 278),
#              ('들어맞는', 6),
#              ('예측', 15),
#              ('카리스마', 48),
#              ('악역', 40),
#              ('불알이', 1),
#              ('나와서', 309),
#              ('당황', 9),
#              ('아무튼', 70),
#              ('중간에', 326),
#              ('끝나는', 101),
#              ('평범함속에', 3),
#              ('녹아든', 6),
#              ('일상', 28),
#              ('밋밋한게', 2),
#              ('보던거라', 1),
#              ('계속보고있는데', 1),
#              ('전개도', 106),
#              ('느리고', 32),
#              ('주인공인', 19),
#              ('은희는', 1),
#              ('한두컷', 1),
#              ('나오면서', 22),
#              ('소극적인모습에', 1),
#              ('짜증이', 61),
#              ('ㅜㅜ', 491),
#              ('맨날', 111),
#              ('언제끝나나', 5),
#              ('기대만하고있어요', 1),
#              ('전개좀', 1),
#              ('빨리빨리', 5),
#              ('사랑하고싶게하는', 1),
#              ('가슴속온감정을헤집어놓는영화예요정말최고', 1),
#              ('많은', 764),
#              ('사람들이', 338),
#              ('다큐를', 36),
#              ('우리나라', 315),
#              ('슬픈', 167),
#              ('현대사의', 3),
#              ('한', 1379),
#              ('단면에', 3),
#              ('대해', 335),
#              ('깊이', 88),
#              ('생각하고', 117),
#              ('사죄하고', 1),
#              ('바로', 323),
#              ('잡기', 3),
#              ('위해', 427),
#              ('노력했으면', 1),
#              ('말로만', 8),
#              ('듣던', 8),
#              ('보도연맹', 1),
#              ('민간인', 6),
#              ('학살이', 2),
#              ('이정도', 115),
#              ('일', 77),
#              ('줄이야', 52),
#              ('명백한', 15),
#              ('살인입니다', 1),
#              ('살인자들은', 1),
#              ('어디있나요', 1),
#              ('예전', 75),
#              ('작품', 1004),
#              ('캐릭터', 244),
#              ('에피소드', 39),
#              ('재탕', 14),
#              ('삼탕', 5),
#              ('사골우려먹듯', 1),
#              ('우리고', 2),
#              ('내용은', 429),
#              ('산으로', 110),
#              ('가고', 67),
#              ('시청률은', 18),
#              ('아예안나오고', 1),
#              ('이제', 536),
#              ('70회중반인데', 1),
#              ('120부작이라니', 1),
#              ('김남길의', 4),
#              ('백점짜리', 1),
#              ('연기력과', 42),
#              ('초반', 121),
#              ('몰입도에도', 1),
#              ('불구하고', 135),
#              ('손예진', 19),
#              ('ㅈㅈ', 1),
#              ('재밌네', 115),
#              ('비슷한', 177),
#              ('영화를', 2836),
#              ('안보신', 9),
#              ('분들한테는', 1),
#              ('재미있을', 26),
#              ('노래실력으로뽑는게', 1),
#              ('맞냐', 12),
#              ('박시환이', 2),
#              ('mama나가면', 1),
#              ('망신이다', 4),
#              ('일본영화', 85),
#              ('다이런건가', 1),
#              ('유치하다', 108),
#              ('이틀만에', 6),
#              ('봤어요', 424),
#              ('재밌어요', 573),
#              ('근데', 844),
#              ('차', 28),
#              ('안에', 77),
#              ('넣어', 17),
#              ('조작하려고', 1),
#              ('하면', 221),
#              ('안이', 2),
#              ('열려있다던지', 1),
#              ('집', 36),
#              ('활짝', 7),
#              ('열려서', 1),
#              ('아무나', 47),
#              ('들어간다던가', 1),
#              ('문자를', 1),
#              ('조작하려고하면', 1),
#              ('비번이', 2),
#              ('안', 946),
#              ('걸려있고', 1),
#              ('그런', 527),
#              ('억지스러웠는데', 2),
#              ('그래도', 901),
#              ('내용', 537),
#              ('자체는', 83),
#              ('졸작', 326),
#              ('재밋네요', 37),
#              ('달팽이가', 3),
#              ('빨라서', 11),
#              ('더', 3309),
#              ('재밌었어요', 186),
#              ('어설픈', 348),
#              ('전개', 346),
#              ('어이없는', 165),
#              ('결말', 322),
#              ('부패한', 6),
#              ('로마노프', 1),
#              ('왕조를', 1),
#              ('기리는', 4),
#              ('뭣같은', 6),
#              ('온몸으로', 5),
#              ('항거했던', 1),
#              ('러시아', 34),
#              ('민중들이', 1),
#              ('폭도냐', 1),
#              ('내용전개는', 3),
#              ('무난한', 20),
#              ('편이였구', 1),
#              ('보았습니다', 92),
#              ('매우', 435),
#              ('실망', 237),
#              ('한국영화', 208),
#              ('흥행코드', 1),
#              ('갈등', 31),
#              ('계', 2),
#              ('에속', 1),
#              ('화해', 6),
#              ('남발', 9),
#              ('흥행', 42),
#              ('뻔하지', 16),
#              ('뭐', 1163),
#              ('아햏햏', 3),
#              ('뭐냐', 271),
#              ('시작하고', 15),
#              ('3분만에', 6),
#              ('나왔다', 66),
#              ('리플릿', 1),
#              ('사진', 22),
#              ('보며', 107),
#              ('불안하더니만', 1),
#              ('단연', 105),
#              ('최고라고', 52),
#              ('할수있지', 5),
#              ('감독이', 645),
#              ('럼먹고', 1),
#              ('만들었나보다', 3),
#              ('관객에게', 36),
#              ('뭘', 400),
#              ('말하는지도', 3),
#              ('모르겠고', 120),
#              ('엉망진창', 22),
#              ('개진창이다', 1),
#              ('우뢰매냐', 1),
#              ('정말쓰레기영화입니다', 1),
#              ('진정', 102),
#              ('위대한', 113),
#              ('최고임', 94),
#              ('별루', 111),
#              ('였다', 37),
#              ('내일이', 11),
#              ('기대되는', 33),
#              ('조미가', 1),
#              ('막문위', 1),
#              ('좋아한건가요', 1),
#              ('골깜', 1),
#              ('ㅋㅋ', 2553),
#              ('눈', 109),
#              ('부라릴때', 1),
#              ('쓰러짐', 1),
#              ('성룡영화중', 9),
#              ('최악인듯', 10),
#              ('골때리네ㅋㅋㅋㅋ', 1),
#              ('걸스데이', 2),
#              ('이혜리', 1),
#              ('되라', 7),
#              ('서기가이뻐서', 1),
#              ('재밌어요ㅋㅋㅋㅋㅋ백인공주귀여움ㅋㅋㅋㅋㅋㅋ', 1),
#              ('인상적인', 58),
#              ('영화였다', 336),
#              ('어내스트와', 1),
#              ('셀레스틴', 2),
#              ('강추에요', 6),
#              ('재밌습니다', 155),
#              ('재미있는영화입니다', 1),
#              ('클라라볼라고화신본거아닌데', 1),
#              ('슬펐던', 16),
#              ('영화다', 1156),
#              ('설정이', 56),
#              ('재밌고', 370),
#              ('새로운', 267),
#              ('내에서', 6),
#              ('메인', 13),
#              ('차차', 1),
#              ('나오는게', 22),
#              ('재밌음', 383),
#              ('신카이', 4),
#              ('마코토의', 2),
#              ('작화와', 2),
#              ('미유와', 1),
#              ('하나카나가', 1),
#              ('연기를', 384),
#              ('잘해줘서', 3),
#              ('더대박이였다', 1),
#              ('재미없음', 387),
#              ('진심', 562),
#              ('1이훨나', 1),
#              ('캐스팅두못한듯', 1),
#              ('잔잔한게', 10),
#              ('생각보다', 334),
#              ('볼만한', 265),
#              ('영화인거', 27),
#              ('같습니다', 192),
#              ('감독님들', 2),
#              ('고은님', 1),
#              ('쓰면', 20),
#              ('영화안봅니다', 1),
#              ('무섭지도', 112),
#              ('않았고', 32),
#              ('영화속', 53),
#              ('억지스럽고', 50),
#              ('노골적인', 13),
#              ('술광고를', 1),
#              ('좀', 2654),
#              ('은은하고', 3),
#              ('센스있게', 2),
#              ('했으면', 82),
#              ('어땠을까', 26),
#              ('킬링타임', 60),
#              ('크리스마스하면', 2),
#              ('떠오르는영화', 2),
#              ('재미있게', 761),
#              ('봤습니다', 554),
#              ('매력적인', 172),
#              ('행복이네요', 1),
#              ("'", 117),
#              ('ㅎㅎㅎ', 244),
#              ('음악에', 30),
#              ('빠져서', 59),
#              ('볼', 968),
#              ('있었던', 158),
#              ('쫌', 123),
#              ('산만하긴', 2),
#              ('하던데', 37),
#              ('태어나서', 79),
#              ('처음으로', 217),
#              ('영화보다', 205),
#              ('나왔습니다', 28),
#              ('불륜이', 9),
#              ('로맨스냐', 6),
#              ('왕짜증', 11),
#              ('아주', 870),
#              ('전개를', 22),
#              ('짬뽕으로', 1),
#              ('믹스했구나', 1),
#              ('음향만', 2),
#              ('무섭게하네', 1),
#              ('하아', 85),
#              ('별루더라', 1),
#              ('시간낭비느낌', 1),
#              ('대박', 514),
#              ('시청률', 107),
#              ('기준이', 17),
#              ('되는', 452),
#              ('패널가구들', 1),
#              ('머하는거지', 1),
#              ('명작드라마', 2),
#              ('망치네', 9),
#              ('서운하다', 2),
#              ('내용이', 660),
#              ('이상해', 39),
#              ('몬스터', 12),
#              ('주식회사', 2),
#              ('3d', 39),
#              ('재밌게', 1359),
#              ('봤다', 769),
#              ('내용전개가', 26),
#              ('너무나', 480),
#              ('느리다', 9),
#              ('소재는', 197),
#              ('흥미를', 55),
#              ('끌지만', 2),
#              ('이야기', 727),
#              ('전개가', 256),
#              ('투박해서', 2),
#              ('몰입이', 144),
#              ('안되는군', 7),
#              ('보지마라', 100),
#              ('쓰레기', 1602),
#              ('중국인', 10),
#              ('특유의', 215),
#              ('과장', 7),
#              ('허풍', 4),
#              ('있어보이려고', 12),
#              ('안간힘', 3),
#              ('쓴', 137),
#              ('노력은', 21),
#              ('가상하나', 4),
#              ('고증과', 2),
#              ('현실감', 20),
#              ('떨어지는', 139),
#              ('거북스럽다', 2),
#              ('도대체', 620),
#              ('그들은', 35),
#              ('이렇게까지', 47),
#              ('스스로를', 18),
#              ('과대포장하는', 1),
#              ('것인지', 27),
#              ('불법체류자', 7),
#              ('때려잡는', 6),
#              ('영화면', 28),
#              ('좋았을텐데', 63),
#              ('우상화를', 1),
#              ('만든다고', 10),
#              ('미국의', 68),
#              ('따뜻한', 231),
#              ('설정', 132),
#              ('뭥미', 71),
#              ('2년의', 1),
#              ('삶속에', 3),
#              ('주인공의', 164),
#              ('생애가', 2),
#              ('전부', 241),
#              ('드러난', 16),
#              ('하다', 283),
#              ('별점10점가자', 1),
#              ('별로다', 194),
#              ('본지', 70),
#              ('지난', 167),
#              ('후에', 60),
#              ('남기지만', 3),
#              ('재미있었음', 59),
#              ('아니', 399),
#              ('이게', 1827),
#              ('9점대', 23),
#              ('일까', 9),
#              ('10년이', 76),
#              ('지나', 36),
#              ('보게된', 45),
#              ('다시봐도', 253),
#              ('순수한', 170),
#              ('사랑에', 150),
#              ('ㅠㅠ', 1371),
#              ('숀펜의', 4),
#              ('연기또한', 6),
#              ('甲', 10),
#              ('올레에', 1),
#              ('공짜로있길래', 1),
#              ('봤음', 253),
#              ('헐', 228),
#              ('스토리가', 710),
#              ('문제가아니라', 1),
#              ('연기자들이', 16),
#              ('전혀', 904),
#              ('배역이랑', 2),
#              ('어울리지않음', 1),
#              ('그리고', 1848),
#              ('상대배우들하고', 1),
#              ('따로', 69),
#              ('노는거같음', 1),
#              ('연기자들도', 13),
#              ('문제있음', 2),
#              ('보아는', 4),
#              ('별로임', 89),
#              ('라미란하고', 1),
#              ('아들이', 63),
#              ('젤', 120),
#              ('볼만했음', 30),
#              ('욕심이', 18),
#              ('많았던', 24),
#              ('어느', 197),
#              ('쪽만이라도', 1),
#              ('보여줬다면', 3),
#              ('빵점', 55),
#              ('베댓이', 2),
#              ('말을', 127),
#              ('잘써놨네', 1),
#              ('모자라진', 1),
#              ('않다', 337),
#              ('도둑들이나', 2),
#              ('뫼비우스', 3),
#              ('나라에서', 10),
#              ('만들어졌다는게', 5),
#              ('믿어지냐', 1),
#              ('온몸이', 6),
#              ('찌릿', 1),
#              ('짜릿', 5),
#              ('나두', 15),
#              ('용기를', 22),
#              ('가져야지', 1),
#              ('정말재미있고', 2),
#              ('교훈적인', 16),
#              ('영화이네요', 10),
#              ('당시의', 25),
#              ('상황과', 22),
#              ('주제를', 85),
#              ('주입식이', 1),
#              ('긴장감있고', 11),
#              ('전하는', 14),
#              ('케이블에서', 75),
#              ('그만', 238),
#              ('나와줬으면', 4),
#              ('다르덴', 4),
#              ('이냐리투', 6),
#              ('차이밍량이', 1),
#              ('안섞인채', 1),
#              ('짬뽕', 16),
#              ('그릇에', 2),
#              ('담겨있다', 10),
#              ('여군', 4),
#              ('잼없음', 39),
#              ('뭐하는건지', 10),
#              ('ㅡㅡ잼없음', 1),
#              ('엠비씨', 10),
#              ('다잼없음', 1),
#              ('질린다이제', 1),
#              ('좋구나', 9),
#              ('한석규', 27),
#              ('김혜수', 24),
#              ('연기만', 45),
#              ('돋보인', 21),
#              ('어딘지', 5),
#              ('모르게', 105),
#              ('많이', 1505),
#              ('에볼라바이러스가', 1),
#              ('떠들석해서', 1),
#              ('보게된영화인데', 2),
#              ('작품성이나', 3),
#              ('어떤면에서도', 1),
#              ('20여년전', 5),
#              ('영화라고보기엔', 1),
#              ('믿기힘들정도로', 1),
#              ('잘만들었다고본다', 1),
#              ('마지막후반부가', 1),
#              ('살짝', 149),
#              ('아쉽긴하지만', 7),
#              ('이정도면', 162),
#              ('수작이라고본다', 1),
#              ('시간이', 611),
#              ('아깝지않은영화', 3),
#              ('볼만해', 11),
#              ('재미있다고', 32),
#              ('떨지', 1),
#              ('마세요', 139),
#              ('용가리', 17),
#              ('진짜짱짱맨이다ㅋ', 1),
#              ('이제서야', 95),
#              ('보다니', 77),
#              ('감히', 101),
#              ('내', 1703),
#              ('인생', 424),
#              ('최고의', 2261),
#              ('하나로', 73),
#              ('꼽을', 19),
#              ('있을만한', 3),
#              ('어떻게', 783),
#              ('살아야할지', 4),
#              ('나를', 178),
#              ('고민을', 18),
#              ('하게', 197),
#              ('시간', 693),
#              ('모건', 9),
#              ('프리먼은', 1),
#              ('나이가', 66),
#              ('들어도', 39),
#              ('여전히', 178),
#              ('섹시하다', 15),
#              ('작가가별로다', 1),
#              ('내용이진짜별로임', 1),
#              ('맨날그냥기대하고', 1),
#              ('재방송하면', 1),
#              ('혹시나하고봐줘도', 1),
#              ('답없다진짜', 1),
#              ('명작도', 11),
#              ('이런', 3484),
#              ('명작이', 52),
#              ('봐도', 915),
#              ('여운이', 603),
#              ('남는', 508),
#              ('조금만', 53),
#              ('손', 38),
#              ('왠만한', 59),
#              ('상업', 12),
#              ('못지', 20),
#              ('않게', 136),
#              ('퀄리티', 45),
#              ('쩔게', 4),
#              ('만들어', 226),
#              ('질', 39),
#              ('있었는데', 91),
#              ('아쉽네요', 106),
#              ('충분히', 281),
#              ('재미있었습니다', 60),
#              ('개인적으로', 522),
#              ('잔인하게', 28),
#              ('자극적으로', 9),
#              ('노출씬도', 2),
#              ('화끈하게', 26),
#              ('했더라면', 6),
#              ...])

# %%
# 전체 단어토큰 확인
len(tokenizer.word_index)
# Out:
# 296310

# %% [markdown]
# #### 빈도가 낮은 제거할 단어들을 알아보자

# %%
df = pd.DataFrame(tokenizer.word_counts.items(),
                  columns=['word', 'count'])
# Out:
#             word  count
# 0             영화  18995
# 1             너무   8563
# 2             정말   8537
# 3             진짜   6682
# 4              이   5418
# ...          ...    ...
# 296305       년이다      1
# 296306     공산당들은      1
# 296307  말이필요없는걸작      1
# 296308     음악이예술      1
# 296309      수간하는      1
#
# [296310 rows x 2 columns]

# %%
df_sorted = df.sort_values(by='count', ascending=False).reset_index()[['word', 'count']]

# %%
# 등장빈도가 20번 미만인 데이터는 제거
df_sorted[df_sorted['count']<20]
# Out:
#             word  count
# 6382       느낌이었다     19
# 6383          경우     19
# 6384          줘야     19
# 6385         했다고     19
# 6386         살아갈     19
# ...          ...    ...
# 296305       년이다      1
# 296306     공산당들은      1
# 296307  말이필요없는걸작      1
# 296308     음악이예술      1
# 296309      수간하는      1
#
# [289928 rows x 2 columns]

# %%
# 20번 미만의 단어들을 제거하기 위해 6382위 단어까지만 남겨놓자
final_tokenizer = Tokenizer(num_words=6382)

# %%
final_tokenizer.fit_on_texts(X_train)

# %%
# 실제 리뷰를 숫자로 인코딩
X_train_seq = final_tokenizer.texts_to_sequences(X_train)
X_test_seq = final_tokenizer.texts_to_sequences(X_test)
X_train_seq
# Out:
# [[23, 936, 4, 1097],
#  [602, 6117],
#  [],
#  [73, 356, 27, 33],
#  [107, 5354, 1, 852, 568],
#  [592, 2290, 51, 4218, 409],
#  [1098, 2234, 134],
#  [111, 1254, 58, 2741, 3],
#  [714, 96, 37, 4915, 1],
#  [1187, 40, 285, 3285, 2, 928],
#  [],
#  [655],
#  [2235, 6118, 38],
#  [87, 150, 60, 518, 283],
#  [3647, 4, 1974, 229, 20, 295, 61, 416, 146, 300, 5127],
#  [2327],
#  [31, 377, 6, 1111],
#  [7, 1361, 263],
#  [24, 3, 13, 432],
#  [257, 190],
#  [174, 4082, 37, 113, 6, 18, 190, 307],
#  [162, 165, 253],
#  [116, 176, 71, 4083, 76, 3744, 230, 418, 24, 70, 3286, 1283, 70, 2939, 67],
#  [190, 767, 19, 148],
#  [3068, 310, 3186, 232],
#  [12, 233, 10, 59],
#  [],
#  [640],
#  [],
#  [1034, 3003, 668, 233, 800],
#  [42, 167, 1476, 768, 2564, 1885, 38, 3, 506, 29],
#  [23, 3964],
#  [447, 2615, 569],
#  [199, 3965, 25],
#  [145, 5, 673, 45],
#  [78, 5587, 5588],
#  [282],
#  [2565, 4551],
#  [4219, 5828],
#  [5, 19, 7, 30, 5829, 248],
#  [6119, 1],
#  [130, 55, 55, 244, 186, 29, 1, 1362, 76, 409, 29, 5830],
#  [],
#  [3, 428, 233, 56, 2566, 56, 41, 4552, 479],
#  [221, 1307, 1627, 322, 4084, 427, 2236, 200, 1179, 350, 1211, 33, 2357, 69],
#  [],
#  [948, 278, 5128, 1768, 5129, 200, 4743, 2472, 2053, 263],
#  [5355, 49, 15, 161, 363, 681, 239],
#  [47, 1975],
#  [163, 1001, 158, 93, 2204, 142, 221, 5130, 5, 142, 614, 608, 279, 3004, 1828],
#  [19, 789, 4220, 196, 929, 2669, 2205, 2742, 140],
#  [1547, 1284],
#  [30, 20, 609, 56, 351, 104, 17, 1131],
#  [292, 65, 2291, 444, 6, 630, 4085],
#  [344],
#  [213, 241],
#  [45],
#  [2, 1118, 1342, 57, 124, 244, 26, 568, 2510, 211, 3, 5131, 219, 682],
#  [],
#  [],
#  [191, 398, 2616, 26, 3124],
#  [357, 1797, 19, 332, 1225, 124],
#  [767, 4383, 200, 602],
#  [1165, 3840, 5589, 2054, 210, 1119, 210],
#  [],
#  [108,
#   313,
#   5,
#   3447,
#   15,
#   347,
#   698,
#   52,
#   320,
#   1406,
#   1055,
#   337,
#   242,
#   427,
#   17,
#   1075,
#   1628,
#   2411,
#   24,
#   12],
#  [1678, 72, 456, 3187, 238, 1132, 1886, 183],
#  [3005, 1019, 899, 176],
#  [1076, 653, 11, 4744, 113],
#  [4],
#  [23, 1461, 1154],
#  [12,
#   246,
#   169,
#   95,
#   4384,
#   1629,
#   507,
#   4384,
#   3448,
#   2670,
#   77,
#   51,
#   188,
#   253,
#   84,
#   182,
#   1497,
#   506],
#  [333],
#  [3365, 9, 618],
#  [302, 305, 710, 339],
#  [1, 3648, 211],
#  [6120, 13, 1343],
#  [235, 469],
#  [543, 3966, 3966, 3966, 104, 33, 69, 3006, 63],
#  [],
#  [410, 1916, 5590, 1160],
#  [1180, 2412],
#  [143, 11, 3449, 264, 1035, 5591],
#  [24, 410],
#  [],
#  [1212, 1099, 1, 1308],
#  [1120, 3366],
#  [3745],
#  [95],
#  [51, 4, 16, 1145, 16],
#  [16],
#  [13],
#  [],
#  [29],
#  [2172, 317],
#  [29, 3, 769],
#  [],
#  [],
#  [4, 162, 2, 64],
#  [2237, 281, 417, 3187, 146, 5592, 274],
#  [271],
#  [269, 173],
#  [323, 419, 4553, 595, 49],
#  [6121],
#  [1112, 3841, 146, 67],
#  [2358, 2511, 14, 1523, 4745],
#  [2089],
#  [],
#  [110, 180, 674, 1056, 1056, 457],
#  [4086, 1118, 2131, 75, 10, 756, 1, 1002, 3367],
#  [1587, 515, 552, 332, 4385],
#  [89, 5593, 1462],
#  [73, 47],
#  [197],
#  [1161, 224, 12, 67, 25, 12],
#  [136, 3188],
#  [3189, 54, 106],
#  [4746, 215],
#  [577, 2292, 118, 433, 827],
#  [190, 1238, 46, 1],
#  [521, 878, 5831, 6122, 861, 2237, 149, 3527, 7, 2671, 4554],
#  [6, 4386, 2000, 65, 1855, 483, 930, 24, 1769],
#  [715, 462, 113, 389],
#  [],
#  [589],
#  [1798, 285, 699, 2090, 2132],
#  [266, 35, 7, 5356],
#  [1650, 3450, 42, 2816, 1, 438, 17, 683, 794, 104, 53],
#  [439, 16, 490, 122, 83, 34, 12, 1829, 24, 173, 29, 1393, 2001, 1036, 4087],
#  [2, 5132, 1, 578, 52, 134],
#  [23, 2293],
#  [964, 89],
#  [89, 316],
#  [1, 93, 71],
#  [5594],
#  [],
#  [4916, 5595, 1463, 148, 54, 72],
#  [1679, 468],
#  [244],
#  [3190],
#  [],
#  [4555, 5133, 2817, 5832, 1, 1181, 48, 302, 1],
#  [73, 3, 801, 731, 153],
#  [],
#  [3842, 862],
#  [],
#  [5,
#   11,
#   1295,
#   1630,
#   1226,
#   39,
#   247,
#   22,
#   295,
#   1718,
#   10,
#   72,
#   102,
#   645,
#   257,
#   167,
#   9,
#   579,
#   224,
#   129,
#   34,
#   1917,
#   3191,
#   646],
#  [],
#  [8, 2413, 351, 158, 15, 56, 81, 157, 198, 1],
#  [23,
#   4,
#   2359,
#   9,
#   3287,
#   14,
#   60,
#   2133,
#   1,
#   6123,
#   887,
#   2818,
#   496,
#   3192,
#   10,
#   1363,
#   1166,
#   84,
#   391,
#   2091,
#   192,
#   2359,
#   9,
#   4387,
#   9,
#   4747,
#   4745,
#   57,
#   48,
#   113,
#   4748],
#  [5596, 3125, 183, 1799, 4749],
#  [23],
#  [44, 206, 2567, 163],
#  [174, 228, 1800],
#  [2, 36, 1],
#  [3, 469],
#  [1447, 647, 7, 4, 161, 60, 7, 5833],
#  [],
#  [7],
#  [69],
#  [53],
#  [1133, 155],
#  [164],
#  [3193, 1524, 285, 189, 3, 847, 1269],
#  [4385, 614, 620, 5134, 17, 4917, 3, 189, 37, 78, 599, 772, 614],
#  [1, 3069],
#  [6124, 457],
#  [64, 675, 1801],
#  [1588, 75, 716, 26, 72],
#  [],
#  [165, 253, 1976, 66, 5597, 101, 414, 2, 70, 116, 1121, 3528, 4750],
#  [1651,
#   374,
#   3529,
#   2092,
#   238,
#   1697,
#   6125,
#   2,
#   1068,
#   173,
#   2473,
#   1296,
#   1407,
#   199,
#   752],
#  [1477, 2940],
#  [470, 1830],
#  [],
#  [5, 1, 25, 7, 4221, 1770, 1887, 5, 18, 6126, 152],
#  [193],
#  [3, 125, 1, 480],
#  [2093, 1953, 81, 724, 758, 1034],
#  [13, 163],
#  [3, 360, 124, 5357, 2206, 3070, 322, 314],
#  [3, 2055],
#  [501,
#   1478,
#   1954,
#   207,
#   136,
#   1918,
#   280,
#   1255,
#   57,
#   284,
#   2,
#   700,
#   276,
#   1680,
#   1364,
#   298,
#   862,
#   6,
#   3746,
#   648],
#  [240],
#  [44, 2670, 1479, 114],
#  [5135],
#  [537, 176, 2360, 4088],
#  [790],
#  [1113, 149, 7, 705, 5596],
#  [72, 15, 158],
#  [39, 22, 1],
#  [2294, 2, 1919, 110, 222, 837, 190],
#  [3843, 4556, 4557, 2, 1],
#  [47, 5358, 199, 279],
#  [1609, 163, 2941],
#  [174, 5598, 879],
#  [949],
#  [35, 581, 476, 4388, 82],
#  [76, 972, 64, 53, 279, 106, 76, 2056],
#  [2878, 196, 10, 37, 3007, 5, 1037, 42, 17, 196, 10, 37, 188, 2474],
#  [406, 1610, 2743, 2414],
#  [189, 263],
#  [104],
#  [2879, 9, 57, 539, 207, 4389, 9],
#  [57, 326, 3530, 462],
#  [34],
#  [23, 3, 2, 3844, 288, 3, 348],
#  [1831, 158],
#  [],
#  [257, 1],
#  [335, 1],
#  [24, 86, 880, 27, 6, 2568, 387],
#  [98, 1155, 281, 221],
#  [44, 3, 4089, 17, 45],
#  [502],
#  [32, 1408, 172],
#  [23, 2, 900, 6127, 39, 5, 1, 418],
#  [1548, 314, 5359, 1, 44, 508, 429, 27],
#  [1631, 3649, 61, 333],
#  [2361, 1],
#  [5834, 1020, 42, 293, 105, 105, 449, 105, 105, 4390, 105, 105, 26, 28],
#  [173, 96, 1100, 2, 33, 1771],
#  [513, 116, 275, 80, 165, 4558, 4751, 261, 4918, 244, 26, 64],
#  [3, 38, 2569, 38, 3, 1464],
#  [2057, 2819, 915],
#  [318, 235, 390, 1800],
#  [1480, 773],
#  [942, 9, 366, 172],
#  [11, 3531, 124, 3194, 233, 42, 1057, 1, 2880],
#  [631, 2, 4391],
#  [1020, 3195, 311, 8, 790, 308, 145, 206, 338, 4090, 68, 1, 3747, 432],
#  [392],
#  [348, 4, 592, 3451, 4, 140],
#  [],
#  [],
#  [102, 8, 3532, 635],
#  [14, 93, 5360, 78, 5835, 13, 248],
#  [14, 6128, 307],
#  [67],
#  [2295, 243, 782],
#  [32, 372, 623, 49],
#  [3533, 1344, 91],
#  [2942, 1498, 1430, 268],
#  [5361, 937, 6129, 596],
#  [425, 217, 143, 3008, 1802, 67],
#  [4752, 460, 2672, 27],
#  [1021, 807, 153, 39, 2820],
#  [211],
#  [4, 4392, 553, 10, 557],
#  [447, 40, 2475, 1955, 324, 1569],
#  [1803, 2512, 4, 3071, 1431],
#  [28, 2],
#  [],
#  [38, 99],
#  [8, 1, 1270, 1020, 5836, 68],
#  [921, 1499, 1477],
#  [],
#  [2204, 116],
#  [114, 2022, 1772, 64, 2415, 2022, 1772, 3967],
#  [1],
#  [377, 5837, 173],
#  [447, 40, 7, 30],
#  [23, 965, 112, 20, 58, 67, 4, 625, 4],
#  [58, 96, 4753, 2134, 2570, 5599, 444],
#  [4393, 1211, 407],
#  [1, 68],
#  [343, 1743, 2, 1134, 219, 1, 1497, 1632, 75, 931, 427],
#  [161, 132, 1956, 3650, 27],
#  [29, 146, 29, 881, 385],
#  [3368],
#  [774],
#  [2296],
#  [35, 1888],
#  [956, 279, 12, 266],
#  [3, 370, 398, 1],
#  [705, 411, 294, 981, 103, 1652, 1773, 4919],
#  [3534, 38, 1345, 5838, 1719, 1101, 180, 432],
#  [35, 1653],
#  [4559],
#  [4222, 3748, 41, 1213, 41, 94, 254],
#  [313,
#   2058,
#   359,
#   1432,
#   372,
#   3651,
#   323,
#   815,
#   95,
#   293,
#   1309,
#   711,
#   2821,
#   1271,
#   423,
#   932],
#  [2237, 340, 682, 66, 179, 107, 5839],
#  [649, 67, 3072, 916, 299],
#  [16, 6, 102, 973, 400, 712, 5136, 783, 16, 5137, 341],
#  [143, 48],
#  [56, 15, 56, 2673, 12],
#  [8, 18, 1135, 2821, 3652, 496, 1977, 1045, 1],
#  [3288],
#  [146, 86, 744, 1957, 2238, 813, 84, 1114],
#  [901, 3968],
#  [40,
#   2,
#   1003,
#   83,
#   650,
#   1500,
#   5138,
#   3369,
#   8,
#   4223,
#   18,
#   6130,
#   6130,
#   83,
#   186,
#   539,
#   70,
#   902,
#   308,
#   15,
#   5,
#   11,
#   411,
#   669],
#  [131, 28],
#  [853],
#  [24, 2206, 3192, 838, 88, 3969, 2744, 1744, 32, 56, 52, 1633, 3196],
#  [204, 651, 1],
#  [53, 2476],
#  [293, 1365, 55, 119, 603, 65, 138],
#  [5, 1, 3, 296],
#  [839, 356, 503],
#  [3, 271, 1136, 2943, 44],
#  [1461, 1102, 3845, 117, 23, 1525],
#  [4224,
#   943,
#   52,
#   19,
#   1654,
#   3370,
#   2411,
#   78,
#   152,
#   3,
#   1655,
#   4394,
#   49,
#   3,
#   1022,
#   109],
#  [77, 656],
#  [1679, 468, 14],
#  [5840, 1297, 370, 100, 86, 27],
#  [102, 973, 6131, 22, 1, 584, 1394, 2944],
#  [88, 32, 2617, 2362],
#  [46, 2135, 3535, 327],
#  [99, 528],
#  [108, 331, 421],
#  [225, 1361, 377, 531, 640, 130, 3, 51],
#  [1632, 2513, 732],
#  [1323, 10, 26],
#  [103, 254, 3, 5841, 53, 438, 139, 957, 1745],
#  [579, 249, 1256],
#  [23, 111],
#  [35, 93, 1, 1285, 263, 3536],
#  [1501, 568, 917],
#  [393, 21],
#  [],
#  [274, 19, 14, 1409, 181, 3846, 5362, 267, 1502, 349, 206, 1346, 12],
#  [2477, 37, 481, 1346, 12, 232, 1447, 201, 4754, 271, 218, 198, 253, 244, 27],
#  [3970, 187, 13, 156, 1920, 1889],
#  [366],
#  [1656],
#  [23, 950, 1324],
#  [944],
#  [1, 1978],
#  [97, 453, 176, 541, 3073],
#  [36, 1856, 3197],
#  [2745],
#  [],
#  [52, 789, 3126, 2239, 3192, 553, 10, 756, 117],
#  [2, 662, 1, 9, 9],
#  [854, 1],
#  [88, 795, 593, 205, 2674],
#  [],
#  [2416, 115, 1180, 5363, 51],
#  [2746],
#  [152, 3009, 83, 966],
#  [],
#  [2618, 174, 14, 662],
#  [5364, 47],
#  [554, 2173],
#  [1058, 154, 903],
#  [19, 434, 2417, 1325, 9, 18, 3653],
#  [231, 103, 1257, 93, 249, 4389],
#  [2136, 2, 945, 386, 418, 603, 2297, 547, 34, 2, 3371],
#  [888, 1, 1286, 2478, 2207],
#  [944, 1023],
#  [447],
#  [116, 372, 29, 306, 29, 1239, 469],
#  [26, 1004, 882],
#  [3289, 153, 175, 1],
#  [244, 26, 1197, 362, 3654, 403, 6132, 2569, 4086],
#  [179, 206, 631, 264, 370, 903],
#  [1774, 4225],
#  [73],
#  [],
#  [93],
#  [1112, 101, 4560, 922],
#  [3970, 26, 2328, 327, 2002, 3010, 1],
#  [5, 18, 184, 6, 188, 196, 4561],
#  [406, 3749, 2479, 901],
#  [439, 48, 50, 334, 168],
#  [149,
#   440,
#   1804,
#   65,
#   5600,
#   2174,
#   593,
#   407,
#   1035,
#   130,
#   580,
#   2023,
#   56,
#   580,
#   689,
#   40,
#   3198],
#  [7,
#   5365,
#   1227,
#   1746,
#   1046,
#   840,
#   34,
#   4562,
#   3750,
#   55,
#   34,
#   7,
#   159,
#   12,
#   4395,
#   1059,
#   27,
#   282,
#   7,
#   990],
#  [2675, 3847, 3074, 255, 46, 1, 12, 15, 2881, 3, 1],
#  [2208, 482, 1103, 422, 320, 231, 1182, 1245, 1921, 222, 1, 4563, 22, 331, 1],
#  [],
#  [2059,
#   147,
#   1347,
#   222,
#   294,
#   717,
#   2,
#   96,
#   308,
#   95,
#   828,
#   519,
#   1634,
#   17,
#   2298,
#   7,
#   234,
#   216,
#   25,
#   2290,
#   375,
#   174,
#   85],
#  [701],
#  [1, 4, 15, 6133],
#  [297, 9],
#  [2676, 1346, 17, 6134, 125, 566, 2137],
#  [430, 1503, 3655, 3, 470, 491, 44],
#  [2299, 90, 146, 2514, 4],
#  [],
#  [2476, 1287, 808, 5139],
#  [],
#  [153, 4396, 165, 2175, 37, 1],
#  [4, 1410, 202, 1188, 1012, 168],
#  [144,
#   182,
#   12,
#   450,
#   945,
#   188,
#   1326,
#   83,
#   1805,
#   225,
#   3069,
#   1958,
#   2297,
#   4920,
#   190,
#   205],
#  [2822, 483],
#  [1258],
#  [213, 3, 110, 180],
#  [340, 5601, 8, 11, 166, 775, 3848, 1411, 1504, 1523, 93, 334, 37, 863, 60],
#  [69, 1240, 375, 229, 21, 3127],
#  [1959, 197, 1481],
#  [3, 737, 3199, 133, 1057, 399, 340, 1298],
#  [3011, 246, 3537, 5842],
#  [43, 132, 1681, 1060, 105, 26, 974, 6],
#  [6, 2024],
#  [1189,
#   932,
#   5140,
#   158,
#   3,
#   5,
#   1,
#   1465,
#   156,
#   230,
#   39,
#   1698,
#   3849,
#   155,
#   3971,
#   3128,
#   59,
#   203,
#   864],
#  [5843, 22, 132, 1],
#  [816,
#   125,
#   1,
#   621,
#   662,
#   37,
#   775,
#   5,
#   18,
#   14,
#   9,
#   3751,
#   52,
#   1122,
#   4564,
#   1146,
#   5844,
#   678],
#  [570, 171, 19, 148],
#  [44, 44],
#  [],
#  [1433],
#  [14, 1806],
#  [23],
#  [738, 53],
#  [97, 8, 3200, 2882],
#  [5141, 2138, 3752, 1832, 5845],
#  [157, 220, 1549, 1],
#  [2883, 223, 1807],
#  [319],
#  [99, 1288, 571],
#  [231, 1699, 1682, 610],
#  [2363, 1635, 1165, 1635, 119, 1635, 394, 116],
#  [4091],
#  [1395],
#  [2, 2240, 335, 1, 3],
#  [1857],
#  [1634, 29, 88, 5602, 9, 2300, 1653],
#  [],
#  [5603, 933, 4921, 5603, 560],
#  [6, 184],
#  [2884, 13, 369, 4561, 513, 3849, 327, 555, 162],
#  [164, 20, 5142],
#  [604, 737, 604],
#  [170, 958, 6135],
#  [4755, 5, 120, 532, 6136],
#  [19, 136, 27],
#  [1922, 3452, 4226],
#  [],
#  [121, 1, 156, 230, 1550, 3201],
#  [166, 1],
#  [1228],
#  [156, 55, 1285, 2329, 57, 27],
#  [208, 1327, 403, 5604, 77, 1229],
#  [548, 548, 128],
#  [1551, 76, 4092],
#  [4397, 865, 60, 9],
#  [3, 3850, 53, 38, 2, 506],
#  [533, 256, 54, 20, 1],
#  [15, 14, 1, 159, 2, 3129, 364, 98, 159, 14, 4398, 93],
#  [572],
#  [3453, 6],
#  [2515, 12, 1552],
#  [179, 483, 119, 12, 506],
#  [3, 4565, 343, 2746, 776, 106],
#  [2675, 3372, 3372, 2364],
#  [3075, 2418],
#  [25, 32, 7, 3202, 1211, 357, 20, 113, 255, 16],
#  [73, 410, 381, 1366, 702],
#  [80, 144, 343, 13, 180, 1259, 56, 1526],
#  [679, 533, 3203, 81, 56, 15, 249, 1],
#  [230, 26],
#  [1239, 145],
#  [814, 626, 2885, 132, 305],
#  [5, 92, 3, 1122, 794, 78, 4399, 841, 4227, 3, 62, 5, 19, 3, 5840],
#  [2677, 2945, 2946],
#  [335, 64],
#  [375, 1, 1570],
#  [1571,
#   466,
#   261,
#   305,
#   1482,
#   150,
#   267,
#   1348,
#   4400,
#   974,
#   315,
#   1553,
#   652,
#   412,
#   982],
#  [2747, 3076, 256, 1],
#  [5, 19, 40, 693, 1167, 160, 160],
#  [991, 1, 577, 570],
#  [189, 2886, 15, 5, 19],
#  [283, 461, 166, 155, 159, 313, 2947],
#  [4, 96, 26, 1, 4401, 138, 1],
#  [2094, 2948, 271, 37, 330, 4093],
#  [],
#  [1700, 4566, 5143, 2887, 4552, 3851, 50, 85],
#  [1434, 796, 1747, 168],
#  [375, 15, 2235, 1916, 16],
#  [3, 22, 1],
#  [1808, 5144, 1, 561, 635, 2301, 1412, 3656],
#  [1367],
#  [466, 141, 38, 105, 267, 153, 76, 175, 520, 1123, 1260, 4756],
#  [292, 5145],
#  [3012, 1589],
#  [4094, 106, 569, 130, 4095, 55, 848, 777, 32],
#  [2571, 2480, 92, 285, 1],
#  [4, 647, 1162, 625, 4],
#  [349, 2678],
#  [1272],
#  [5146, 1572, 42, 491],
#  [],
#  [107, 581, 529, 463, 4096],
#  [],
#  [630, 1890, 2, 58, 1],
#  [62, 45, 16, 4402, 51],
#  [],
#  [528, 266, 45],
#  [46, 3204, 3972],
#  [883, 5846, 77, 975, 1, 115, 105, 3454],
#  [],
#  [298, 156, 55, 2176, 4, 12, 54, 458, 4, 142, 5605, 4922, 255, 3538],
#  [1917, 917],
#  [25, 20, 115, 1168, 573],
#  [44, 1775, 544],
#  [3205, 2679, 1, 1979, 1748, 15, 39],
#  [6, 14, 9, 654, 1169, 5847, 214, 90],
#  [6, 3077, 9, 5147, 18, 654, 2, 6137, 139, 250, 3973],
#  [215, 335, 1],
#  [5, 11],
#  [3753, 367, 429, 1261, 2949, 2365, 848],
#  [240, 32, 15],
#  [],
#  [6122],
#  [2748, 468, 2481, 4923, 1554, 250, 114],
#  [274, 718],
#  [4219, 173, 4567, 2888, 3290],
#  [1161, 3539, 1069, 1328, 641],
#  [189, 76, 447, 7, 1005, 958],
#  [141, 38, 1501, 125, 155, 417, 3455, 4403, 108, 3373, 770, 604],
#  [47, 32, 2366, 3, 25],
#  [35, 102, 40, 889],
#  [2950, 415, 670, 3657, 363],
#  [3754],
#  [69, 3456],
#  [5606, 5848],
#  [490, 415],
#  [1891, 501, 1, 85, 51],
#  [3, 22, 632, 6138, 1],
#  [5148, 549, 1296, 497, 426, 64, 567, 55, 611],
#  [4, 410, 936, 2296],
#  [6, 216, 1246, 53],
#  [],
#  [422],
#  [5366, 218, 1885],
#  [6, 1980],
#  [],
#  [938, 444],
#  [4, 904, 1],
#  [13, 101, 284, 2572, 464, 4757, 719, 83, 379, 80, 165],
#  [974],
#  [314, 54, 180],
#  [],
#  [387, 156, 91],
#  [161, 64, 2290, 37, 5607],
#  [4924, 14],
#  [720, 21, 3, 54, 13, 246, 3755, 2419, 20, 1, 115, 3013],
#  [21, 79],
#  [1273, 379, 123],
#  [521, 753, 38, 649, 38, 2, 1329],
#  [2003, 2510, 1430, 251, 14],
#  [1448, 109, 226, 182, 128],
#  [5849, 2510, 675, 110, 951],
#  [1573, 1744, 539],
#  [315],
#  [185, 2025, 1, 1892, 4568, 193, 43, 225, 4228, 193, 1],
#  [582, 468, 15, 249],
#  [86, 880, 27, 585, 3078, 25, 2482, 50],
#  [471, 3374, 563, 1118, 563],
#  [1809, 44, 2055],
#  [],
#  [44, 1163],
#  [228, 1],
#  [189, 274],
#  [577,
#   31,
#   842,
#   5367,
#   18,
#   3206,
#   4925,
#   148,
#   1923,
#   38,
#   1590,
#   1858,
#   590,
#   1859,
#   74,
#   1413,
#   1156,
#   56,
#   275,
#   801],
#  [191, 1198, 2241],
#  [],
#  [313, 135, 1591],
#  [6],
#  [1449, 4926, 22, 4563],
#  [3540],
#  [1102, 1657, 4404],
#  [24, 1038, 10, 26, 4, 5850, 58],
#  [3974, 1, 327, 2, 990],
#  [1611],
#  [279, 703, 703, 776, 74, 770, 30, 2058, 177],
#  [2951],
#  [1104, 3, 164, 68, 3658],
#  [27],
#  [3541, 357, 167, 1981, 469, 814, 1683, 1365, 4569],
#  [36, 3291, 141],
#  [357, 1527, 2177],
#  [74, 1776, 463, 82, 816, 1, 1497, 122, 4758, 889, 144, 50, 85],
#  [36, 642, 1831, 5, 17, 1396, 3849, 31, 164, 20],
#  [],
#  [4229, 1061],
#  [4759, 3756, 2749, 1002, 428, 3207, 95, 4, 436, 46, 1, 4, 176],
#  [215, 1574, 335, 1],
#  [256, 58, 5368, 2060, 496, 5149],
#  [1247, 2823],
#  [992, 99],
#  [2206, 580, 248, 2330, 1],
#  [1498, 331],
#  [548],
#  [191, 366],
#  [199],
#  [794, 42, 351, 57, 219, 855, 1],
#  [1449, 5851, 515],
#  [45, 9, 2680],
#  [1024],
#  [2026],
#  [67],
#  [342, 105, 15, 80, 57, 2750, 596],
#  [4],
#  [494],
#  [5, 1006, 18, 5369, 9, 325, 615],
#  [3852],
#  [281, 6139, 441],
#  [80, 53, 3542, 4, 53, 159, 210],
#  [1199, 1039, 89, 110, 15],
#  [2095, 636, 218, 3208, 2516, 257, 406, 356, 200, 1397],
#  [1466],
#  [22, 489, 915, 4570, 2669, 124],
#  [39, 247, 22, 1],
#  [4],
#  [1483, 6140, 2, 1447, 4097, 3659, 23, 3457, 630, 5608, 4571],
#  [],
#  [31, 272, 1, 68],
#  [],
#  [83, 293, 1701, 2619, 2242],
#  [],
#  [847, 1040, 905],
#  [185, 3079, 1483],
#  [4, 4927, 474, 2941],
#  [36, 2178, 1450, 3209, 3853],
#  [266, 7, 20, 1610, 3850, 89, 6],
#  [2139, 2952],
#  [182],
#  [],
#  [279, 51],
#  [382],
#  [],
#  [3, 534, 15, 58, 193],
#  [2140],
#  [39, 247, 22, 1, 1650, 145, 1077],
#  [],
#  [4760, 3292, 378, 5, 92, 462],
#  [1, 1070, 921, 1349, 932, 6141, 1, 2096],
#  [1212, 36, 2953, 1330, 1115, 349, 2420, 56, 1777, 1057, 973, 16],
#  [3, 2824],
#  [1720, 1888],
#  [100, 86, 27],
#  [47, 6142],
#  [8, 19, 31, 87],
#  [5370, 5852, 1548, 1702, 330],
#  [82, 82, 3757, 1],
#  [5150, 3, 54, 1524, 57, 312, 133, 16],
#  [1013, 162],
#  [5853, 3660, 66, 1701, 81, 5, 321, 2141],
#  [494, 3539],
#  [1],
#  [73, 33, 1179, 2367],
#  [219, 5371],
#  [1461, 3543, 59, 906, 1],
#  [4,
#   24,
#   2483,
#   1467,
#   1090,
#   95,
#   24,
#   670,
#   13,
#   3130,
#   3014,
#   2142,
#   69,
#   7,
#   1414,
#   469],
#  [254, 3210, 7, 1295],
#  [135, 475],
#  [191, 19, 856, 2671, 431, 351],
#  [4, 30, 3211, 4572, 4],
#  [],
#  [],
#  [16, 1833, 4098, 4928, 391, 1860],
#  [47, 73, 412],
#  [1123, 1, 1960],
#  [725],
#  [266, 167, 102, 545, 2368, 889],
#  [5151,
#   4395,
#   236,
#   1214,
#   245,
#   89,
#   236,
#   4099,
#   1435,
#   233,
#   123,
#   126,
#   103,
#   72,
#   967,
#   17,
#   5854,
#   400],
#  [29, 2954, 53, 68],
#  [231, 2484],
#  [32, 121, 273, 49],
#  [],
#  [71, 1296, 1121],
#  [41, 94, 1612, 6143, 3661, 484],
#  [154, 726, 58, 111, 52, 58],
#  [161],
#  [594, 4, 110],
#  [62, 2209, 5372, 3, 2955, 26, 1410, 3854, 8, 11, 952, 701, 157, 198, 1],
#  [162, 3855, 3975],
#  [9],
#  [],
#  [15, 94, 157, 198, 1],
#  [2369, 1238, 60],
#  [65, 1893, 3976, 248, 1500, 1],
#  [2476,
#   34,
#   1982,
#   482,
#   4230,
#   759,
#   1,
#   4573,
#   4574,
#   2331,
#   2825,
#   4761,
#   864,
#   1575,
#   188,
#   5152,
#   5153,
#   1041],
#  [],
#  [33, 3544, 542, 5373, 2751, 1],
#  [66, 1505, 2179],
#  [73,
#   4575,
#   3545,
#   12,
#   3,
#   2743,
#   1983,
#   2943,
#   297,
#   645,
#   37,
#   5,
#   124,
#   1415,
#   1924,
#   64],
#  [125, 1091],
#  [3],
#  [521, 4231],
#  [3],
#  [2370, 4762, 1],
#  [1524, 120, 794, 120, 57, 189, 2681, 36, 4553, 336],
#  [97, 46, 3],
#  [],
#  [142, 739],
#  [47, 5374],
#  [552, 9, 1078],
#  [2243, 564],
#  [139, 5154, 1749, 100, 10, 351, 22, 2371],
#  [2244, 754, 93, 1467, 120],
#  [2296],
#  [1658, 3660, 72],
#  [4, 8, 255, 3080, 591, 71, 1, 255, 1124, 4576, 25, 1147, 3545, 24, 4],
#  [272, 2027, 8, 1262, 671, 31, 3370, 50, 772, 404, 1480, 404],
#  [],
#  [3],
#  [923, 4577, 3293],
#  [109],
#  [6, 5609, 2826],
#  [1576, 4232, 251, 66, 1436, 2, 68],
#  [111, 4578, 73, 111, 1254, 58],
#  [564, 564, 239, 37, 499, 3966, 57, 328, 2180],
#  [2061],
#  [2485, 10, 557],
#  [195, 789, 4100, 29, 339],
#  [3546, 3375, 599, 9, 2332, 113, 93],
#  [5610, 45, 9],
#  [96],
#  [870, 350, 158, 1075, 280, 1484],
#  [222, 1, 61, 1],
#  [4579,
#   2004,
#   3458,
#   733,
#   6122,
#   26,
#   4929,
#   930,
#   3977,
#   34,
#   5,
#   1,
#   243,
#   76,
#   128,
#   25,
#   3078,
#   456,
#   780,
#   202],
#  [447,
#   694,
#   669,
#   2682,
#   347,
#   3856,
#   244,
#   2939,
#   6,
#   4101,
#   4101,
#   93,
#   531,
#   326,
#   1776,
#   12,
#   993,
#   419,
#   2027],
#  [471, 3647, 3131],
#  [33, 5155],
#  [194, 175, 382, 409],
#  [405, 3081, 3459, 1256, 84, 646, 6144, 813, 50, 2945],
#  [1636, 12, 2136],
#  [1289, 27, 5375, 387],
#  [5855],
#  [485, 58],
#  [1047, 948],
#  [5611, 1829, 1212, 17, 1984],
#  [16],
#  [2062, 95, 689],
#  [4],
#  [143, 1433, 1555, 1062, 45, 1528],
#  [23, 96, 2, 503, 129, 3662],
#  [47, 68],
#  [102, 248, 143, 2683, 249, 34, 5856, 5376, 3758, 608],
#  [5857, 3294, 1290, 1985, 118],
#  [420, 2669],
#  [36, 1],
#  [],
#  [],
#  [152, 3974, 1],
#  [16],
#  [269],
#  [65, 1506],
#  [146, 3663, 179, 119, 4761, 391, 1063],
#  [39, 247, 22, 2028],
#  [5, 11, 15, 474, 312, 2372, 3015, 535, 1331, 4580, 1396, 690],
#  [5377, 1062],
#  [232, 817],
#  [1529, 2333, 1190, 1925, 3295, 1530, 3367],
#  [6],
#  [3547, 2684, 5156, 2373, 656, 1, 49],
#  [3, 6145, 1699, 468],
#  [3548, 14, 441, 12, 253, 2245],
#  [3296, 46],
#  [508, 501, 285, 5157, 1261, 1980, 2334],
#  [1377, 7],
#  [1577, 4233, 1350, 907, 5858],
#  [3376, 4384, 147, 4, 1828],
#  [4, 415, 3212, 1],
#  [],
#  [32, 1531],
#  [6122, 315, 2, 506, 127, 48, 75, 10, 642, 506, 71, 45, 5612, 45],
#  [822, 4930, 84],
#  [],
#  [40, 2, 2210, 2063, 4405, 414, 2029, 139, 1155, 294, 1926, 482, 1103, 186],
#  [404, 2064, 1, 95, 5, 18, 610],
#  [20, 1],
#  [4234, 140],
#  [132, 29, 965, 126, 138, 2674],
#  [],
#  [34, 3857],
#  [724, 1778, 1678, 1525],
#  [3377],
#  [586, 20, 142, 70],
#  [156, 230, 992, 2421],
#  [5613, 4581, 1611, 1703],
#  [3843, 223, 565, 5158, 267, 1498, 1291],
#  [2143, 713, 196, 386, 74, 12, 21, 4, 848, 3964],
#  [7, 3858, 1414, 6146, 244, 3286, 93, 2952, 3759, 65, 126, 1161],
#  [47, 939, 19, 1230, 87],
#  [],
#  [31, 54, 21, 796],
#  [153, 5159, 56, 81, 3, 28, 82, 82],
#  [135, 265, 3, 2058, 818],
#  [],
#  [2207, 72],
#  [338, 13, 248, 264, 680, 57, 903, 5378, 61],
#  [4406],
#  [281, 2752, 62, 296, 381, 1485],
#  [6, 807, 364, 4, 6, 19, 114],
#  [4,
#   732,
#   3,
#   2,
#   110,
#   509,
#   2,
#   1,
#   2753,
#   3,
#   177,
#   4,
#   25,
#   5,
#   4102,
#   2754,
#   1160,
#   5,
#   30],
#  [5160],
#  [1986],
#  [33, 3460, 474, 219, 682],
#  [3978, 489],
#  [42],
#  [3368, 537],
#  [],
#  [16],
#  [1721],
#  [39,
#   808,
#   61,
#   2685,
#   1628,
#   115,
#   337,
#   5,
#   11,
#   3859,
#   500,
#   1575,
#   6147,
#   705,
#   167,
#   59,
#   680,
#   100,
#   1],
#  [323, 107],
#  [518, 264, 242, 65],
#  [80],
#  [217, 53],
#  [1575, 177, 200, 73, 1, 1497, 1448, 624, 1468, 44, 968],
#  [318, 21, 6148, 68, 309],
#  [5614, 74, 776, 20, 25, 142],
#  [],
#  [1891, 224, 1],
#  [516],
#  [6, 5161, 148, 113],
#  [1398, 2684],
#  [43],
#  [171, 157, 48, 757],
#  [97, 1, 2422, 377, 559, 1215, 12, 210],
#  [299, 264, 1146, 4407, 146, 124],
#  [4103, 2573],
#  [752, 4931],
#  [425, 2211],
#  [1332, 1613, 758, 1],
#  [2956, 1, 4085, 56, 1155, 481, 1, 884],
#  [184, 1367, 3549, 2827, 2358, 1469, 241],
#  [816, 360, 5379],
#  [5843, 1399, 1399, 1399, 1399],
#  [22, 72, 1698, 1507, 2828, 57, 1, 213, 2882],
#  [73],
#  [],
#  [359, 399, 3213, 1747, 791, 828, 53],
#  [430, 165, 3204, 4924],
#  [277, 516, 2957, 592, 127, 449, 398],
#  [255, 1451, 1226],
#  [4582, 4932, 2030],
#  [54, 180, 211, 148, 17, 578, 13, 760, 957, 1005, 3132, 154, 107],
#  [2486, 187, 21, 222, 1, 29, 174, 146, 5859, 132, 823, 383, 1, 137, 1, 3550],
#  [3196],
#  [301, 706, 73, 1508, 210],
#  [482, 2335, 350, 8, 98, 4552],
#  [3, 794, 320],
#  [238],
#  [727, 127],
#  [1587, 20, 632, 142, 2958],
#  [507],
#  [6149, 2, 541, 1378, 130, 27],
#  [4, 382, 3378, 1324, 550, 2246, 298, 862],
#  [4933],
#  [],
#  [159, 2671, 13],
#  [4, 30, 156, 55, 300, 26, 18, 4104, 2686, 2889, 101, 1368, 2, 154, 119],
#  [22],
#  [2421,
#   5860,
#   4583,
#   2302,
#   113,
#   414,
#   199,
#   1115,
#   1105,
#   256,
#   5380,
#   373,
#   324,
#   1103],
#  [391, 2247],
#  [5127, 16],
#  [1532, 250, 27, 45],
#  [1927, 36, 1],
#  [],
#  [55, 2097, 27],
#  [347],
#  [5162, 48, 20, 1007, 43],
#  [22, 28],
#  [311],
#  [105, 26, 1697, 12],
#  [],
#  [465, 4934, 1125, 17],
#  [80, 112, 1261, 571, 421, 445, 341, 4235, 994, 556, 61, 1528],
#  [174, 230, 36, 72],
#  [1198],
#  [524],
#  [1722, 252, 201, 1113, 6, 5615],
#  [1452],
#  [5163, 3214, 1155, 2212, 3860, 263, 1161, 592],
#  [70, 76],
#  [2423, 5159, 42, 346, 90, 1961, 1045, 113],
#  [562, 706],
#  [942, 14, 4763, 772, 84, 636, 525],
#  [2478],
#  [857, 2031, 4584, 1113, 238, 1079],
#  [2248, 581, 5, 11, 643],
#  [3664, 6150, 5, 18, 4, 2143],
#  [465],
#  [3082],
#  [],
#  [4, 13, 79, 330],
#  [217],
#  [568, 483, 259, 1071, 1777, 1287, 166, 1],
#  [90, 4105, 703, 1, 1274, 5616],
#  [32,
#   31,
#   577,
#   31,
#   310,
#   4746,
#   2620,
#   1191,
#   418,
#   995,
#   4101,
#   885,
#   12,
#   2065,
#   5381,
#   1292],
#  [2098, 5366, 5617, 878, 1, 29, 3379, 132, 146, 2475],
#  [282, 7, 47],
#  [2, 484, 146, 1116, 2236, 326, 5839],
#  [858, 3380, 2424],
#  [2249, 102],
#  [4935, 6, 949, 402, 141, 5861, 761, 181, 4585, 1351, 2755, 2172, 33, 2],
#  [3979, 206, 1126, 238, 46],
#  [4, 116, 229, 170],
#  [429, 274],
#  [32, 3980, 2959, 160, 160],
#  [35],
#  [],
#  [2, 684, 41, 94],
#  [681, 195, 377, 1960, 1555],
#  [740, 57, 4227, 3297, 92, 356, 308, 817, 1828],
#  [89, 526],
#  [109],
#  [2362, 695, 219, 1],
#  [662, 5862, 349, 567, 975, 1275, 1416, 13, 4399],
#  [4408, 4936, 13, 2066, 22, 3187, 5164, 5618, 2024],
#  [2425, 2425],
#  [668, 1293, 253, 27],
#  [2426, 1, 22, 333],
#  [],
#  [839, 276, 276, 26],
#  [92, 44, 3981, 342, 2, 365],
#  [685, 120, 831, 477, 5, 530],
#  [31, 983, 271, 1470, 57, 51],
#  [],
#  [454, 447, 16],
#  [194, 58, 276, 41, 94, 3215, 196, 550],
#  [372, 745, 21, 1, 41, 94, 1080, 110, 246],
#  [2144, 13, 117, 4236, 150, 286, 1417, 1417, 249, 1],
#  [2250, 2032],
#  [117, 2, 1025, 28, 43, 668, 38, 362, 141, 128],
#  [],
#  [392, 365, 188, 574, 1136, 1183, 3760, 1164, 1231],
#  [88, 755, 157, 48, 198, 28],
#  [453, 289, 575, 119, 575, 3744, 890],
#  [93, 950, 4, 130, 181, 156, 1048],
#  [171],
#  [698],
#  [1399],
#  [],
#  [260],
#  [],
#  [131, 620],
#  [29, 2212, 46, 64, 2181, 2136, 4237],
#  [65],
#  [1684, 1834],
#  [191, 502, 2132],
#  [2, 274],
#  [983],
#  [48, 17, 7, 707],
#  [2133, 24],
#  [275, 3551, 98, 2213, 320, 100, 1685, 27],
#  [3298, 217, 53],
#  [384, 829],
#  [231, 600, 339],
#  [3, 54, 2890, 38, 2, 2960, 168],
#  [73, 4586, 516, 65, 1182],
#  [86, 3299, 23, 173],
#  [942],
#  [99, 2025, 56, 15, 1005],
#  [95, 51],
#  [],
#  [],
#  [20, 2574, 153, 81, 153, 175, 1418, 382],
#  [2954, 2682, 5, 1, 35, 4, 1432, 1081, 1411, 17, 4],
#  [4759, 5382, 4238, 550, 1637, 3461, 143, 3665],
#  [96, 1021],
#  [1547, 1350],
#  [43, 823, 832, 38, 31, 1464, 181, 75, 10, 280, 26],
#  [5165],
#  [306, 2517, 1659, 2033, 42],
#  [7, 944, 196, 10, 1704],
#  [1045, 72],
#  [5863, 234],
#  [35, 282, 65],
#  [24, 4937, 130, 924, 3552, 3552, 63, 436],
#  [612],
#  [1013, 802, 434, 4764, 25, 4764, 1379],
#  [1117, 262],
#  [2374, 1116, 2, 827],
#  [4409, 879, 815],
#  [616, 652, 17, 1750, 191, 4, 31],
#  [1798, 1351, 145, 4587, 4765, 4],
#  [1501, 1352, 1477, 1614, 4410],
#  [4588],
#  [1026],
#  [4, 710, 3861, 458, 255, 1653, 73, 1833, 37],
#  [663, 746, 1592],
#  [3462, 5619, 1, 153, 1020, 222, 19, 17, 19, 337, 1775, 153, 4396, 544],
#  [76, 618, 1962, 457],
#  [140, 102],
#  [5383, 148, 849, 539],
#  [51, 269],
#  [5166, 47, 3300, 20],
#  [118, 378, 2292],
#  [644, 5384, 1310],
#  [29, 168],
#  [1041,
#   1434,
#   1116,
#   2829,
#   4106,
#   1019,
#   1170,
#   12,
#   220,
#   261,
#   41,
#   415,
#   1461,
#   521,
#   17,
#   531],
#  [43, 83, 744, 28, 3463, 72],
#  [328, 414, 2961, 74, 106],
#  [4239, 5, 1008, 15, 79, 253, 3464],
#  [784, 3553, 11, 6151, 7, 1163, 12],
#  [4766, 1326, 423, 2336, 4107, 650, 27, 741, 353, 166, 2332, 284],
#  [1894, 774],
#  [519, 1171, 20, 260, 1, 115, 45],
#  [3083, 99],
#  [655, 2943, 3381, 1058, 4240, 92, 34, 2248],
#  [1578, 2],
#  [2942, 258],
#  [3666],
#  [3667, 40],
#  [1248, 174, 2621],
#  [499, 225, 33, 15, 77, 5620, 1471, 8, 9, 41, 216, 849, 578, 4938, 6, 1182],
#  ...]

# %% [markdown]
# #### 리뷰 시퀀스의 길이를 알아보자

# %%
X_train_len = [len(doc) for doc in X_train_seq]

# %%
print("최대 : ", max(X_train_len))
print("최소 : ", min(X_train_len))
print("평균 : ", np.mean(X_train_len))
print("중앙 : ", np.median(X_train_len))
# Out:
# 최대 :  53
# 최소 :  0
# 평균 :  4.481342711423714
# 중앙 :  3.0

# %%
# 평균과 중앙 사이값으로 맞춰보자
X_train_pad_seq = sequence.pad_sequences(X_train_seq, maxlen=4)
X_test_pad_seq = sequence.pad_sequences(X_test_seq, maxlen=4)

# %%
X_train_pad_seq.shape, X_test_pad_seq.shape
# Out:
# ((149995, 4), (49997, 4))

# %%
X_train_pad_seq[10]
# Out:
# array([0, 0, 0, 0], dtype=int32)

# %% [markdown]
# #### 모델링
# - input_shape 고려
# - 출력층 고려
# - 임베딩 레이어
# - LSTM or GRU
# - 출력층 고려 (2진분류)
# - loss, optimizer 고려
# - 검증셋 분리해서 학습
# - 모델체크포인트, 얼리스타핑 설정
# - 학습결과 시각화
# - test데이터로 모델 평가

# %%
naver_movie_model = Sequential()
naver_movie_model.add(Embedding(6382,50)) # 사용하는 단어사전의 수, 각 단어를 표현할 수(자기맘)
naver_movie_model.add(Dropout(0.4)) # 과대적합을 막기위해 일부로 중간중간 신경망을 끊어버림(epoch마다 꺼지는 신경망 다름), 0.4=40%끔
naver_movie_model.add(LSTM(128,return_sequences=True)) # Dropout은 바로 밑에층에만 적용됨 
naver_movie_model.add(LSTM(128))
naver_movie_model.add(Dense(1,activation='sigmoid'))
naver_movie_model.compile(loss='binary_crossentropy',
            optimizer=Adam(),
            metrics=['accuracy']
            )

mkpt = ModelCheckpoint(filepath='./data/naver_movie_model/naver_movie_model_{epoch:04d}_{val_loss:.3f}.hdf5', 
                       monitor='val_loss', 
                       verbose=1,  # 모델 저장 로그
                       save_best_only=True) 

early = EarlyStopping(monitor='val_loss',
                      verbose=1,
                      patience=10) # 성능개선 안될시 기다려주는 횟수(그 이내에 개선되면 횟수 리셋, 개선안되면 멈춤)

h1 = naver_movie_model.fit(X_train_pad_seq,y_train,epochs=100, validation_split=0.2,callbacks=[mkpt, early])
# Out:
# Epoch 1/100
# 3750/3750 [==============================] - ETA: 0s - loss: 0.4824 - accuracy: 0.7487
# Epoch 1: val_loss improved from inf to 0.44656, saving model to ./data/naver_movie_model/naver_movie_model_0001_0.447.hdf5
# 3750/3750 [==============================] - 106s 26ms/step - loss: 0.4824 - accuracy: 0.7487 - val_loss: 0.4466 - val_accuracy: 0.7737
# Epoch 2/100
# 3750/3750 [==============================] - ETA: 0s - loss: 0.4300 - accuracy: 0.7822
# Epoch 2: val_loss improved from 0.44656 to 0.44027, saving model to ./data/naver_movie_model/naver_movie_model_0002_0.440.hdf5
# 3750/3750 [==============================] - 93s 25ms/step - loss: 0.4300 - accuracy: 0.7822 - val_loss: 0.4403 - val_accuracy: 0.7780
# Epoch 3/100
# 3750/3750 [==============================] - ETA: 0s - loss: 0.4123 - accuracy: 0.7892
# Epoch 3: val_loss did not improve from 0.44027
# 3750/3750 [==============================] - 103s 28ms/step - loss: 0.4123 - accuracy: 0.7892 - val_loss: 0.4455 - val_accuracy: 0.7756
# Epoch 4/100
# 3749/3750 [============================>.] - ETA: 0s - loss: 0.3978 - accuracy: 0.7972
# Epoch 4: val_loss did not improve from 0.44027
# 3750/3750 [==============================] - 95s 25ms/step - loss: 0.3978 - accuracy: 0.7972 - val_loss: 0.4467 - val_accuracy: 0.7759
# Epoch 5/100
# 3749/3750 [============================>.] - ETA: 0s - loss: 0.3855 - accuracy: 0.8044
# Epoch 5: val_loss did not improve from 0.44027
# 3750/3750 [==============================] - 92s 25ms/step - loss: 0.3855 - accuracy: 0.8044 - val_loss: 0.4517 - val_accuracy: 0.7724
# Epoch 6/100
# 3750/3750 [==============================] - ETA: 0s - loss: 0.3757 - accuracy: 0.8085
# Epoch 6: val_loss did not improve from 0.44027
# 3750/3750 [==============================] - 91s 24ms/step - loss: 0.3757 - accuracy: 0.8085 - val_loss: 0.4608 - val_accuracy: 0.7714
# Epoch 7/100
# 3749/3750 [============================>.] - ETA: 0s - loss: 0.3661 - accuracy: 0.8143
# Epoch 7: val_loss did not improve from 0.44027
# 3750/3750 [==============================] - 96s 26ms/step - loss: 0.3661 - accuracy: 0.8143 - val_loss: 0.4673 - val_accuracy: 0.7695
# Epoch 8/100
# 3750/3750 [==============================] - ETA: 0s - loss: 0.3586 - accuracy: 0.8180
# Epoch 8: val_loss did not improve from 0.44027
# 3750/3750 [==============================] - 90s 24ms/step - loss: 0.3586 - accuracy: 0.8180 - val_loss: 0.4704 - val_accuracy: 0.7686
# Epoch 9/100
# 3749/3750 [============================>.] - ETA: 0s - loss: 0.3503 - accuracy: 0.8232
# Epoch 9: val_loss did not improve from 0.44027
# 3750/3750 [==============================] - 92s 24ms/step - loss: 0.3503 - accuracy: 0.8232 - val_loss: 0.4930 - val_accuracy: 0.7691
# Epoch 10/100
# 3749/3750 [============================>.] - ETA: 0s - loss: 0.3417 - accuracy: 0.8270
# Epoch 10: val_loss did not improve from 0.44027
# 3750/3750 [==============================] - 89s 24ms/step - loss: 0.3417 - accuracy: 0.8270 - val_loss: 0.4948 - val_accuracy: 0.7656
# Epoch 11/100
# 3748/3750 [============================>.] - ETA: 0s - loss: 0.3336 - accuracy: 0.8318
# Epoch 11: val_loss did not improve from 0.44027
# 3750/3750 [==============================] - 91s 24ms/step - loss: 0.3336 - accuracy: 0.8318 - val_loss: 0.5019 - val_accuracy: 0.7652
# Epoch 12/100
# 3749/3750 [============================>.] - ETA: 0s - loss: 0.3267 - accuracy: 0.8350
# Epoch 12: val_loss did not improve from 0.44027
# 3750/3750 [==============================] - 90s 24ms/step - loss: 0.3267 - accuracy: 0.8350 - val_loss: 0.5292 - val_accuracy: 0.7638
# Epoch 12: early stopping

# %%
plt.figure(figsize=(15,5))
plt.plot(h1.history['accuracy'], label='train_acc')
plt.plot(h1.history['val_accuracy'], label='val_acc')
plt.legend()
plt.show()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-81-c01756b713b7> in <module>
#       1 plt.figure(figsize=(15,5))
# ----> 2 plt.plot(h1.history['accuracy'], label='train_acc')
#       3 plt.plot(h1.history['val_accuracy'], label='val_acc')
#       4 plt.legend()
#       5 plt.show()
#
# NameError: name 'h1' is not defined
